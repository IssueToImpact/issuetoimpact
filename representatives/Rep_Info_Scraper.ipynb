# %%
import bs4
import requests
import html5lib
import time
import json
import csv
import re

# %%
base_url = "http://www.ilga.gov"
senate_url = base_url + "/senate/"
house_url = base_url + "/house/"

# %% [markdown]
# #### Grab html

# %%
def url_to_soup(url):
    r = requests.get(url)
    html_text = r.text.encode('iso-8859-1')
    return bs4.BeautifulSoup(html_text, "html5lib")

# %%
rep_info = {}

# %%
def update_rep_dict(rep_info, url, chamber):
    soup = url_to_soup(url)
    tablerow_tags = soup.find_all('td', class_ = "detail")
    for i in range(0,len(tablerow_tags),5):
        name = tablerow_tags[i].a.text
        rep_info[name] = {}
        committees_link = url + tablerow_tags[i+2].a["href"]
        district = tablerow_tags[i+3].text
        party = tablerow_tags[i+4].text
        rep_info[name]['party'] = party
        rep_info[name]['district'] = str(chamber) + ' ' + str(district)
        rep_info[name]['committees'] = []
    
        #Go to committees page and grab committees
        committee_soup = url_to_soup(committees_link)
        com_table_tags = committee_soup.find_all('td', class_="billlist")
        for tag in com_table_tags:
            if tag.a and 'hearing' in tag.a['href']:
                committee_id = re.findall(r'ID=([\d]{4})', tag.a['href'])[0]
                rep_info[name]['committees'].append((tag.text.strip(), committee_id))  
        rep_info[name]['bills'] = {'ids': [], 'count sponsored': 0, 'count passed': 0, 'topic counts':{}}

# %%
update_rep_dict(rep_info, senate_url, 'Senate')
update_rep_dict(rep_info, house_url, 'House')

# %%
rep_info
# Out:
# {'Neil Anderson': {'party': 'R',
#   'district': 'Senate 36',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Omar Aquino': {'party': 'D',
#   'district': 'Senate 2',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Executive', '2320'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Higher Education', '2333'),
#    ('Labor', '2334'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Sub. on Traffic Safety Systems', '2651'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Subcommittee on Charter Schools', '2555'),
#    ('Subcommittee on Procurement', '2650')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jason A. Barickman': {'party': 'R',
#   'district': 'Senate 53',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Judiciary', '2345'),
#    ('Labor', '2334'),
#    ('Sub. on the Const.& Redistricting', '2625'),
#    ('Subcommittee on Gov. Operations', '2561'),
#    ('Subcommittee on Special Issues (CL)', '2609'),
#    ('Subcommittee on Special Issues (ED)', '2554')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Christopher Belt': {'party': 'D',
#   'district': 'Senate 57',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Subcommittee on Special Issues (IN)', '2642')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Scott M. Bennett': {'party': 'D',
#   'district': 'Senate 52',
#   'committees': [('Agriculture', '2316'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Higher Education', '2333'),
#    ('Labor', '2334'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('State Government', '2322'),
#    ('Subcommittee on Capital (AP)', '2591')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jennifer Bertino-Tarrant': {'party': 'D',
#   'district': 'Senate 49',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Subcommittee on Special Issues (ED)', '2554'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'William E. Brady': {'party': 'R',
#   'district': 'Senate 44',
#   'committees': [('Committee of the Whole', '2332'), ('Executive', '2320')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Melinda Bush': {'party': 'D',
#   'district': 'Senate 31',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Environment and Conservation', '2344'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Revenue', '2326'),
#    ('Sub. on Interscholastic Athletics', '2556'),
#    ('Sub. on Tax Exemptions and Credits', '2616'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Cristina Castro': {'party': 'D',
#   'district': 'Senate 22',
#   'committees': [('Appropriations I', '2317'),
#    ('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Labor', '2334'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Revenue', '2326'),
#    ('Subcommittee on Special Issues (RE)', '2653'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jacqueline Y. Collins': {'party': 'D',
#   'district': 'Senate 16',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Financial Institutions', '2321'),
#    ('Insurance', '2323'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Rachelle Crowe': {'party': 'D',
#   'district': 'Senate 56',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Judiciary', '2345'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Sub. on the Const.& Redistricting', '2625'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Subcommittee on Tort Reform', '2628'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Thomas Cullerton': {'party': 'D',
#   'district': 'Senate 23',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('State Government', '2322'),
#    ('Sub. on Utility Rate Regulations', '2631'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Bill Cunningham': {'party': 'D',
#   'district': 'Senate 18',
#   'committees': [('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'John F. Curran': {'party': 'R',
#   'district': 'Senate 41',
#   'committees': [('Appropriations II', '2329'),
#    ('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Local Government', '2324'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Donald P. DeWitte': {'party': 'R',
#   'district': 'Senate 33',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Local Government', '2324'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Revenue', '2326'),
#    ('Sub. on Tax Exemptions and Credits', '2616'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Subcommittee on Local Policies', '2636'),
#    ('Subcommittee on Special Issues (RE)', '2653'),
#    ('Telecommunications & InfoTechnology', '2375'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Laura Ellman': {'party': 'D',
#   'district': 'Senate 21',
#   'committees': [('Agriculture', '2316'),
#    ('Appropriations I', '2317'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Higher Education', '2333'),
#    ('Subcommittee on Special Issues (EP)', '2630'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Sara Feigenholtz': {'party': 'D',
#   'district': 'House 12',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Laura Fine': {'party': 'D',
#   'district': 'Senate 9',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Human Services', '2330'),
#    ('Insurance', '2323'),
#    ('Local Government', '2324'),
#    ('Public Health', '2337'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Local Policies', '2636'),
#    ('Subcommittee on Special Issues (IN)', '2642')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dale Fowler': {'party': 'R',
#   'district': 'Senate 59',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Ann Gillespie': {'party': 'D',
#   'district': 'Senate 27',
#   'committees': [('Appropriations I', '2317'),
#    ('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Insurance', '2323'),
#    ('Judiciary', '2345'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Civil Rights', '2626'),
#    ('Subcommittee on Firearms', '2627')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Suzy Glowiak Hilton': {'party': 'D',
#   'district': 'Senate 24',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Local Government', '2324'),
#    ('Sub. on Utility Rate Regulations', '2631')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Don Harmon': {'party': 'D',
#   'district': 'Senate 39',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Executive', '2320'),
#    ('Judiciary', '2345'),
#    ('Subcommittee on Business Entities', '2624')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Napoleon Harris, III': {'party': 'D',
#   'district': 'Senate 15',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Executive', '2320'),
#    ('Human Services', '2330'),
#    ('Insurance', '2323'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Subcommittee on Procurement', '2650'),
#    ('Supplier Diversity, Special Com. On', '2610'),
#    ('Telecommunications & InfoTechnology', '2375')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Michael E. Hastings': {'party': 'D',
#   'district': 'Senate 19',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Insurance', '2323'),
#    ('Judiciary', '2345'),
#    ('Subcommittee on Election Law', '2558'),
#    ('Subcommittee on Firearms', '2627'),
#    ('Subcommittee on Gaming', '2559'),
#    ('Subcommittee on Special Issues (EP)', '2630'),
#    ('Subcommittee on Tort Reform', '2628')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Linda Holmes': {'party': 'D',
#   'district': 'Senate 42',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Executive', '2320'),
#    ('Labor', '2334'),
#    ('Local Government', '2324'),
#    ('Subcommittee on Cannabis', '2649'),
#    ('Telecommunications & InfoTechnology', '2375')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Mattie Hunter': {'party': 'D',
#   'district': 'Senate 3',
#   'committees': [('Appropriations I', '2317'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Human Services', '2330'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Public Health', '2337'),
#    ('Sub. on Traffic Safety Systems', '2651'),
#    ('Subcommittee on Special Issues (EX)', '2560'),
#    ('Subcommittee on Special Issues (HS)', '2629'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Emil Jones, III': {'party': 'D',
#   'district': 'Senate 14',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Financial Institutions', '2321'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Licensed Activities', '2325'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Patrick J. Joyce': {'party': 'D',
#   'district': 'Senate 40',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Labor', '2334'),
#    ('Local Government', '2324'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Public Health', '2337')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'David Koehler': {'party': 'D',
#   'district': 'Senate 46',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Environment and Conservation', '2344'),
#    ('Labor', '2334'),
#    ('Local Government', '2324'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Sub. on Interscholastic Athletics', '2556'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Supplier Diversity, Special Com. On', '2610'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Steven M. Landek': {'party': 'D',
#   'district': 'Senate 12',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Insurance', '2323'),
#    ('Local Government', '2324'),
#    ('State Government', '2322'),
#    ('Subcommittee on Local Policies', '2636')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Kimberly A. Lightford': {'party': 'D',
#   'district': 'Senate 4',
#   'committees': [('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Charter Schools', '2555'),
#    ('Subcommittee on Const. Amendments', '2557'),
#    ('Subcommittee on Gov. Operations', '2561'),
#    ('Supplier Diversity, Special Com. On', '2610')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Terry Link': {'party': 'D',
#   'district': 'Senate 30',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Financial Institutions', '2321'),
#    ('Insurance', '2323'),
#    ('Subcommittee on Gaming', '2559')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Andy Manar': {'party': 'D',
#   'district': 'Senate 48',
#   'committees': [('Agriculture', '2316'),
#    ('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Executive Appointments', '2319'),
#    ('Labor', '2334'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Subcommittee on Special Issues (ED)', '2554')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Iris Y. Martinez': {'party': 'D',
#   'district': 'Senate 20',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Revenue', '2326'),
#    ('Subcommittee on Const. Amendments', '2557'),
#    ('Subcommittee on Gov. Operations', '2561'),
#    ('Subcommittee on Special Issues (RE)', '2653'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Robert F. Martwick': {'party': 'D',
#   'district': 'Senate 10',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Judiciary', '2345'),
#    ('Licensed Activities', '2325'),
#    ('Public Health', '2337'),
#    ('Revenue', '2326')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Steve McClure': {'party': 'R',
#   'district': 'Senate 50',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Energy and Public Utilities', '2343'),
#    ('Higher Education', '2333'),
#    ('Local Government', '2324'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Public Health', '2337'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('State Government', '2322'),
#    ('Sub. on Utility Rate Regulations', '2631'),
#    ('Subcommittee on CLEAR Compliance', '2608'),
#    ('Subcommittee on Prisons', '2612'),
#    ('Supplier Diversity, Special Com. On', '2610')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dan McConchie': {'party': 'R',
#   'district': 'Senate 26',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Public Health', '2337'),
#    ('State Government', '2322'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Supplier Diversity, Special Com. On', '2610'),
#    ('Telecommunications & InfoTechnology', '2375')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Pat McGuire': {'party': 'D',
#   'district': 'Senate 43',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Higher Education', '2333'),
#    ('Revenue', '2326'),
#    ('State Government', '2322'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Subcommittee on Prisons', '2612'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Julie A. Morrison': {'party': 'D',
#   'district': 'Senate 29',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Human Services', '2330'),
#    ('Local Government', '2324'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Public Health', '2337'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Antonio Muñoz': {'party': 'D',
#   'district': 'Senate 1',
#   'committees': [('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Insurance', '2323'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Laura M. Murphy': {'party': 'D',
#   'district': 'Senate 28',
#   'committees': [('Assignments', '2341'),
#    ('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Financial Institutions', '2321'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Local Government', '2324'),
#    ('Public Health', '2337'),
#    ('Subcommittee on Election Law', '2558')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jim Oberweis': {'party': 'R',
#   'district': 'Senate 25',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Executive', '2320'),
#    ('Labor', '2334'),
#    ('Revenue', '2326'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Subcommittee on Election Law', '2558'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Robert Peters': {'party': 'D',
#   'district': 'Senate 13',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Financial Institutions', '2321'),
#    ('Human Services', '2330'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Telecommunications & InfoTechnology', '2375'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jason Plummer': {'party': 'R',
#   'district': 'Senate 54',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Executive Appointments', '2319'),
#    ('Financial Institutions', '2321'),
#    ('Public Health', '2337')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Sue Rezin': {'party': 'R',
#   'district': 'Senate 38',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Revenue', '2326'),
#    ('Sub. on Interscholastic Athletics', '2556'),
#    ('Subcommittee on Special Issues (EX)', '2560')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dale A. Righter': {'party': 'R',
#   'district': 'Senate 55',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Human Services', '2330'),
#    ('Insurance', '2323'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Const. Amendments', '2557'),
#    ('Subcommittee on Special Issues (HS)', '2629')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Chapin Rose': {'party': 'R',
#   'district': 'Senate 51',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Financial Institutions', '2321'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Capital (AP)', '2591')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Paul Schimpf': {'party': 'R',
#   'district': 'Senate 58',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Financial Institutions', '2321'),
#    ('Judiciary', '2345'),
#    ('Subcommittee on Civil Rights', '2626'),
#    ('Subcommittee on Firearms', '2627'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Elgie R. Sims, Jr.': {'party': 'D',
#   'district': 'Senate 17',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Judiciary', '2345'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Sub. on the Const.& Redistricting', '2625'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Subcommittee on Civil Rights', '2626'),
#    ('Subcommittee on CLEAR Compliance', '2608'),
#    ('Subcommittee on Special Issues (CL)', '2609'),
#    ('Telecommunications & InfoTechnology', '2375')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Steve Stadelman': {'party': 'D',
#   'district': 'Senate 34',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Financial Institutions', '2321'),
#    ('Higher Education', '2333'),
#    ('Public Health', '2337'),
#    ('Revenue', '2326'),
#    ('Telecommunications & InfoTechnology', '2375'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Heather A. Steans': {'party': 'D',
#   'district': 'Senate 7',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Human Services', '2330'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Cannabis', '2649'),
#    ('Subcommittee on Special Issues (EX)', '2560'),
#    ('Subcommittee on Special Issues (HS)', '2629')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Brian W. Stewart': {'party': 'R',
#   'district': 'Senate 45',
#   'committees': [('Appropriations I', '2317'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Executive Appointments', '2319'),
#    ('Human Services', '2330'),
#    ('Insurance', '2323'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dave Syverson': {'party': 'R',
#   'district': 'Senate 35',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Executive', '2320'),
#    ('Human Services', '2330'),
#    ('Insurance', '2323'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Public Health', '2337'),
#    ('Subcommittee on Gaming', '2559')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jil Tracy': {'party': 'R',
#   'district': 'Senate 47',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Executive Appointments', '2319'),
#    ('Judiciary', '2345'),
#    ('Labor', '2334'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('State Government', '2322'),
#    ('Subcommittee on Business Entities', '2624'),
#    ('Subcommittee on Tort Reform', '2628'),
#    ('Supplier Diversity, Special Com. On', '2610'),
#    ('Telecommunications & InfoTechnology', '2375')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Patricia Van Pelt': {'party': 'D',
#   'district': 'Senate 5',
#   'committees': [('Agriculture', '2316'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Energy and Public Utilities', '2343'),
#    ('Higher Education', '2333'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Public Health', '2337'),
#    ('State Government', '2322'),
#    ('Subcommittee on CLEAR Compliance', '2608'),
#    ('Subcommittee on Prisons', '2612')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Celina Villanueva': {'party': 'D',
#   'district': 'House 21',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Ram Villivalam': {'party': 'D',
#   'district': 'Senate 8',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Human Services', '2330'),
#    ('Labor', '2334'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Supplier Diversity, Special Com. On', '2610'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Chuck Weaver': {'party': 'R',
#   'district': 'Senate 37',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Charter Schools', '2555'),
#    ('Transportation', '2327')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Craig Wilcox': {'party': 'R',
#   'district': 'Senate 32',
#   'committees': [('Agriculture', '2316'),
#    ('Appropriations I', '2317'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Human Services', '2330'),
#    ('Labor', '2334'),
#    ('Subcommittee on Special Issues (EP)', '2630'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'John J. Cullerton': {'party': 'D',
#   'district': 'Senate 6',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Toi W. Hutchinson': {'party': 'D',
#   'district': 'Senate 40',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'John G. Mulroe': {'party': 'D',
#   'district': 'Senate 10',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Martin A. Sandoval': {'party': 'D',
#   'district': 'Senate 11',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Carol Ammons': {'party': 'D',
#   'district': 'House 103',
#   'committees': [('Appropriations-Higher Education', '2296'),
#    ('Energy & Environment', '2355'),
#    ('Environmental Justice Subcommittee', '2595'),
#    ('Higher Education', '2305'),
#    ('Miscellaneous Issues Subcommittee', '2614'),
#    ('Personnel & Pensions', '2310'),
#    ('Public Utilities', '2311'),
#    ('Special Issues Subcommittee (HED)', '2640')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jaime M. Andrade, Jr.': {'party': 'D',
#   'district': 'House 40',
#   'committees': [('Amusement & Online Gaming Sub', '2598'),
#    ('Appropriations-Capital', '2550'),
#    ('Broadband Access and IT Assurance', '2597'),
#    ('Commerce and Innovation Subcommitte', '2569'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Distributed Ledgers & Cryptocurrenc', '2599'),
#    ('Election Process & Cybersecurity', '2645'),
#    ('Financial Institutions', '2303'),
#    ('Human Services', '2306'),
#    ('Labor & Commerce', '2309')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Darren Bailey': {'party': 'R',
#   'district': 'House 109',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Approp-Elementary & Secondary Educ', '2293'),
#    ('Appropriations-Human Services', '2295'),
#    ('Child Care Access & Early Childhood', '2551'),
#    ('Elem Sec Ed: Adm., Lic. & Charter', '2361'),
#    ('Energy & Environment', '2355')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Mark Batinick': {'party': 'R',
#   'district': 'House 97',
#   'committees': [('Administrative and Substantive', '2613'),
#    ('Health Care Licenses', '2349'),
#    ('Insurance', '2552'),
#    ('International Trade & Commerce', '2335'),
#    ('Pension Reform Subcommittee', '2615'),
#    ('Personnel & Pensions', '2310')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Thomas M. Bennett': {'party': 'R',
#   'district': 'House 106',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Child Care Access & Early Childhood', '2551'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Health Care Availability & Access', '2304'),
#    ('Income Tax Subcommittee', '2588'),
#    ('Labor & Commerce', '2309'),
#    ('Revenue & Finance', '2352'),
#    ('Special Issues Subcommittee (AES)', '2576')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Avery Bourne': {'party': 'R',
#   'district': 'House 95',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Appropriations-Capital', '2550'),
#    ('Counties & Townships', '2348'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('International Trade & Commerce', '2335'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Special Issues Subcommittee (AES)', '2576'),
#    ('Special Issues Subcommittee (ESS)', '2600')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dan Brady': {'party': 'R',
#   'district': 'House 105',
#   'committees': [('Appropriations-Higher Education', '2296'),
#    ('Consumer Protection', '2298'),
#    ('Counties & Townships', '2348'),
#    ('Health Insurance Subcommittee', '2582'),
#    ('Higher Education', '2305'),
#    ('Insurance', '2552'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Rules', '2312'),
#    ('Special Issues Subcommittee (HED)', '2640'),
#    ('Special Subcommittee (INS)', '2581')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Monica Bristow': {'party': 'D',
#   'district': 'House 111',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Economic Opportunity & Equity', '2381'),
#    ('Higher Education', '2305'),
#    ('Human Services', '2306'),
#    ('Mental Health', '2389'),
#    ('Negotiations Subcommittee (AGCS)', '2622'),
#    ('Prescription Drug Affordability', '2553'),
#    ("Veterans' Affairs", '2315')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Terri Bryant': {'party': 'R',
#   'district': 'House 115',
#   'committees': [('Appropriations-Higher Education', '2296'),
#    ('Criminal Administration and Enforce', '2601'),
#    ('Firearms and Firearm Safety', '2602'),
#    ('Health Care Licenses', '2349'),
#    ('Higher Education', '2305'),
#    ('Human Services', '2306'),
#    ('Insurance', '2552'),
#    ('Judiciary - Criminal', '2362'),
#    ('Juvenile Justice and System Involve', '2603'),
#    ('Sentencing, Penalities and Criminal', '2604'),
#    ('Sex Offenses and Sex Offender Reg.', '2605')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Kambium Buckner': {'party': 'D',
#   'district': 'House 26',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Child Care Access & Early Childhood', '2551'),
#    ('Firearms and Firearm Safety', '2602'),
#    ('Higher Education', '2305'),
#    ('Judiciary - Criminal', '2362'),
#    ('Transportation: Vehicles & Safety', '2351')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Kelly M. Burke': {'party': 'D',
#   'district': 'House 36',
#   'committees': [('Administrative and Substantive', '2613'),
#    ('Agriculture & Conservation', '2331'),
#    ('Appropriations-Higher Education', '2296'),
#    ('Elem Sec Ed: Adm., Lic. & Charter', '2361'),
#    ('Health Care Licenses', '2349'),
#    ('Higher Education', '2305'),
#    ('Museums, Arts, & Cultural Enhanceme', '2356'),
#    ('Pension Reform Subcommittee', '2615'),
#    ('Personnel & Pensions', '2310'),
#    ('Personnel Code Subcommittee', '2562'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Special Issues Subcommittee (ESE)', '2587'),
#    ('Special Issues Subcommittee (HED)', '2640')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Tim Butler': {'party': 'R',
#   'district': 'House 87',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Appropriations-Public Safety', '2297'),
#    ('Capital Issues Subcommittee', '2643'),
#    ('Energy & Environment', '2355'),
#    ('Executive', '2302'),
#    ('Museums, Arts, & Cultural Enhanceme', '2356'),
#    ('Public Utilities', '2311'),
#    ('Transportation: Vehicles & Safety', '2351')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'John M. Cabello': {'party': 'R',
#   'district': 'House 68',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Appropriations-Public Safety', '2297'),
#    ('Judiciary - Criminal', '2362'),
#    ('Labor & Commerce', '2309'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Transportation: Regulation, Roads', '2350')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jonathan Carroll': {'party': 'D',
#   'district': 'House 57',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Consolidation & Tax Subcommittee', '2593'),
#    ('Counties & Townships', '2348'),
#    ('Financial Institutions', '2303'),
#    ('Health Care Licenses', '2349'),
#    ('Insurance', '2552'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Revenue & Finance', '2352')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Kelly M. Cassidy': {'party': 'D',
#   'district': 'House 14',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Appropriations-Public Safety', '2297'),
#    ('Business and Industry Regulations S', '2570'),
#    ('Facilities Subcommittee', '2577'),
#    ('Firearms and Firearm Safety', '2602'),
#    ('Human Services', '2306'),
#    ('Informed Consent Subcommittee', '2580'),
#    ('Judiciary - Criminal', '2362'),
#    ('Labor & Commerce', '2309'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Wage Policy and Study Subcommittee', '2567')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dan Caulkins': {'party': 'R',
#   'district': 'House 101',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Energy & Environment', '2355'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Public Utilities', '2311')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Andrew S. Chesney': {'party': 'R',
#   'district': 'House 89',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Appropriations-Human Services', '2295'),
#    ('Cities & Villages', '2347'),
#    ('Constitutional Law Subcommittee', '2572'),
#    ('Economic Opportunity & Equity', '2381'),
#    ('Judiciary - Civil', '2308'),
#    ('Mental Health', '2389')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'John Connor': {'party': 'D',
#   'district': 'House 85',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Appropriations-Higher Education', '2296'),
#    ('Broadband Access and IT Assurance', '2597'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Distributed Ledgers & Cryptocurrenc', '2599'),
#    ('Election Process & Cybersecurity', '2645'),
#    ('Firearms and Firearm Safety', '2602'),
#    ('Job Growth, Preservation and Traini', '2566'),
#    ('Judiciary - Criminal', '2362'),
#    ('Labor & Commerce', '2309'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Sentencing, Penalities and Criminal', '2604'),
#    ('Transportation: Regulation, Roads', '2350')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Deb Conroy': {'party': 'D',
#   'district': 'House 46',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Financial Institutions', '2303'),
#    ('Insurance', '2552'),
#    ('Mental Health', '2389'),
#    ('Special Issues Subcommittee (ESS)', '2600')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Terra Costa Howard': {'party': 'D',
#   'district': 'House 48',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Cities & Villages', '2347'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Family Law Subcommittee', '2574'),
#    ('Judiciary - Civil', '2308'),
#    ('Mental Health', '2389'),
#    ("Veterans' Affairs", '2315')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Fred Crespo': {'party': 'D',
#   'district': 'House 44',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Elem Sec Ed: Adm., Lic. & Charter', '2361'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Mental Health', '2389'),
#    ('Public Utilities', '2311'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Special Investigating Comm.', '2646'),
#    ('Special Issues Subcommittee (ESE)', '2587'),
#    ('Special Issues Subcommittee (ESS)', '2600')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  "John C. D'Amico": {'party': 'D',
#   'district': 'House 15',
#   'committees': [('Labor & Commerce', '2309'),
#    ('Special Issues Subcommittee (TRN)', '2607'),
#    ('Special Issues Subcommittee (TVS)', '2586'),
#    ('Transportation: Regulation, Roads', '2350'),
#    ('Transportation: Vehicles & Safety', '2351'),
#    ("Veterans' Affairs", '2315'),
#    ('Wage Policy and Study Subcommittee', '2567')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'C.D. Davidsmeyer': {'party': 'R',
#   'district': 'House 100',
#   'committees': [('Appropriations-Public Safety', '2297'),
#    ('Child Care Access & Early Childhood', '2551'),
#    ('Financial Institutions', '2303'),
#    ('Health Care Licenses', '2349'),
#    ('Insurance', '2552'),
#    ('Negotiations Subcommittee (NEGS)', '2594'),
#    ('Public Utilities', '2311'),
#    ('Renewable Initiatives Subcommittee', '2623'),
#    ('Special Subcommittee (FIN)', '2621')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'William Davis': {'party': 'D',
#   'district': 'House 30',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Appropriations-Capital', '2550'),
#    ('Appropriations-Public Safety', '2297'),
#    ('Energy & Environment', '2355'),
#    ('Environmental Justice Subcommittee', '2595'),
#    ('International Trade & Commerce', '2335'),
#    ('Labor & Commerce', '2309'),
#    ('Minority/Disadvantage Analysis Subc', '2568'),
#    ('Special Issues Subcommittee (AES)', '2576')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Eva Dina Delgado': {'party': 'D',
#   'district': 'House 3',
#   'committees': [('Appropriations-Human Services', '2295'),
#    ('Insurance', '2552'),
#    ('Mental Health', '2389'),
#    ('Transportation: Regulation, Roads', '2350')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Anthony DeLuca': {'party': 'D',
#   'district': 'House 80',
#   'committees': [('Amusement & Online Gaming Sub', '2598'),
#    ('Broadband Access and IT Assurance', '2597'),
#    ('Cities & Villages', '2347'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Health Care Licenses', '2349'),
#    ('Health Insurance Subcommittee', '2582'),
#    ('Insurance', '2552'),
#    ('Local Government Subcommittee', '2596'),
#    ('Special Subcommittee (INS)', '2581')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Tom Demmer': {'party': 'R',
#   'district': 'House 90',
#   'committees': [('Amusement & Online Gaming Sub', '2598'),
#    ('Appropriations-Human Services', '2295'),
#    ('Broadband Access and IT Assurance', '2597'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Facilities Subcommittee', '2577'),
#    ('Health Care Availability & Access', '2304'),
#    ('Human Services', '2306'),
#    ('Informed Consent Subcommittee', '2580'),
#    ('Medicaid & Managed Care Subcommitte', '2632'),
#    ('Medicaid Subcommittee', '2579'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Public Benefits Subcommittee', '2578'),
#    ('Rules', '2312')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Daniel Didech': {'party': 'D',
#   'district': 'House 59',
#   'committees': [('Commercial Law Subcommittee', '2573'),
#    ('Consolidation & Tax Subcommittee', '2593'),
#    ('Counties & Townships', '2348'),
#    ('Energy & Environment', '2355'),
#    ('Family Law Subcommittee', '2574'),
#    ('Government Process Subcommittee', '2620'),
#    ('Judiciary - Civil', '2308'),
#    ('State Government Administration', '2313')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jim Durkin': {'party': 'R',
#   'district': 'House 82',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Mary Edly-Allen': {'party': 'D',
#   'district': 'House 51',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Energy & Environment', '2355'),
#    ('Human Services', '2306'),
#    ('Mental Health', '2389'),
#    ('Special Issues (ACSI)', '2639'),
#    ('State Government Administration', '2313')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Marcus C. Evans, Jr.': {'party': 'D',
#   'district': 'House 33',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Business and Industry Regulations S', '2570'),
#    ('Commerce and Innovation Subcommitte', '2569'),
#    ('Executive', '2302'),
#    ('Income Tax Subcommittee', '2588'),
#    ('Job Growth, Preservation and Traini', '2566'),
#    ('Labor & Commerce', '2309'),
#    ('Minority/Disadvantage Analysis Subc', '2568'),
#    ('Revenue & Finance', '2352'),
#    ('Transportation: Regulation, Roads', '2350'),
#    ('Transportation: Vehicles & Safety', '2351'),
#    ('Wage Policy and Study Subcommittee', '2567'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Mary E. Flowers': {'party': 'D',
#   'district': 'House 31',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Health Care Availability & Access', '2304'),
#    ('Human Services', '2306'),
#    ('Prescription Drug Affordability', '2553')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'La Shawn K. Ford': {'party': 'D',
#   'district': 'House 8',
#   'committees': [('Appropriations-Higher Education', '2296'),
#    ('Financial Institutions', '2303'),
#    ('Miscellaneous Issues Subcommittee', '2614'),
#    ('Personnel & Pensions', '2310'),
#    ('Public Utilities', '2311'),
#    ('Special Subcommittee (FIN)', '2621')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Randy E. Frese': {'party': 'R',
#   'district': 'House 94',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Appropriations-Human Services', '2295'),
#    ('Child Care Access & Early Childhood', '2551'),
#    ('Health Care Licenses', '2349'),
# ...
#   'district': 'House 69',
#   'committees': [('Child Care Access & Early Childhood', '2551'),
#    ('Cities & Villages', '2347'),
#    ('Elem Sec Ed: Adm., Lic. & Charter', '2361'),
#    ('Executive', '2302'),
#    ('Income Tax Subcommittee', '2588'),
#    ('Revenue & Finance', '2352'),
#    ('Special Issues Subcommittee (ESE)', '2587')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Ryan Spain': {'party': 'R',
#   'district': 'House 73',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Capital Issues Subcommittee', '2643'),
#    ('Executive', '2302'),
#    ('Financial Institutions', '2303'),
#    ('Mental Health', '2389'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Public Utilities', '2311')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Anne Stava-Murray': {'party': 'D',
#   'district': 'House 81',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Election Process & Cybersecurity', '2645'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Judiciary - Criminal', '2362'),
#    ('Juvenile Justice and System Involve', '2603'),
#    ('Museums, Arts, & Cultural Enhanceme', '2356')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Bradley Stephens': {'party': 'R',
#   'district': 'House 20',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Financial Institutions', '2303'),
#    ('Health Care Licenses', '2349'),
#    ('Mental Health', '2389'),
#    ("Veterans' Affairs", '2315')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Katie Stuart': {'party': 'D',
#   'district': 'House 112',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Consumer Protection', '2298'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Higher Education', '2305'),
#    ('Labor & Commerce', '2309'),
#    ('Museums, Arts, & Cultural Enhanceme', '2356'),
#    ('Special Issues Subcommittee (HED)', '2640'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Daniel Swanson': {'party': 'R',
#   'district': 'House 74',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Appropriations-Public Safety', '2297'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Mental Health', '2389'),
#    ("Veterans' Affairs", '2315')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Curtis J. Tarver, II': {'party': 'D',
#   'district': 'House 25',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Child Care Access & Early Childhood', '2551'),
#    ('Commercial Law Subcommittee', '2573'),
#    ('Family Law Subcommittee', '2574'),
#    ('Financial Institutions', '2303'),
#    ('Judiciary - Civil', '2308')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'André Thapedi': {'party': 'D',
#   'district': 'House 32',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Capital Issues Subcommittee', '2643'),
#    ('Civil Procedure Subcommittee', '2571'),
#    ('Commercial Law Subcommittee', '2573'),
#    ('Constitutional Law Subcommittee', '2572'),
#    ('Energy & Environment', '2355'),
#    ('International Trade & Commerce', '2335'),
#    ('Judiciary - Civil', '2308'),
#    ('Public Utilities', '2311')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Arthur Turner': {'party': 'D',
#   'district': 'House 9',
#   'committees': [('Amusement & Online Gaming Sub', '2598'),
#    ('Criminal Administration and Enforce', '2601'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Executive', '2302'),
#    ('Income Tax Subcommittee', '2588'),
#    ('Judiciary - Criminal', '2362'),
#    ('Public Utilities', '2311'),
#    ('Regulatory Matters Subcommittee', '2618'),
#    ('Renewable Initiatives Subcommittee', '2623'),
#    ('Revenue & Finance', '2352'),
#    ('Rules', '2312'),
#    ('Sales, Amusement & Other Taxes', '2590')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Dan Ugaste': {'party': 'R',
#   'district': 'House 65',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Appropriations-Capital', '2550'),
#    ('Energy & Environment', '2355'),
#    ('Health Care Licenses', '2349'),
#    ('Labor & Commerce', '2309'),
#    ('Museums, Arts, & Cultural Enhanceme', '2356'),
#    ('Special Investigating Comm.', '2646')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Michael D. Unes': {'party': 'R',
#   'district': 'House 91',
#   'committees': [('Financial Institutions', '2303'),
#    ('Insurance', '2552'),
#    ('International Trade & Commerce', '2335'),
#    ('Museums, Arts, & Cultural Enhanceme', '2356'),
#    ('Special Issues Subcommittee (TVS)', '2586'),
#    ('Transportation: Vehicles & Safety', '2351'),
#    ("Veterans' Affairs", '2315')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Karina Villa': {'party': 'D',
#   'district': 'House 49',
#   'committees': [('Approp-Elementary & Secondary Educ', '2293'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Health Care Availability & Access', '2304'),
#    ('Labor & Commerce', '2309'),
#    ('Mental Health', '2389'),
#    ('Special Issues Subcommittee (ESS)', '2600'),
#    ("Veterans' Affairs", '2315'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Mark L. Walker': {'party': 'D',
#   'district': 'House 53',
#   'committees': [('Counties & Townships', '2348'),
#    ('Economic Opportunity & Equity', '2381'),
#    ('Financial Institutions', '2303'),
#    ('Insurance', '2552'),
#    ('International Trade & Commerce', '2335')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Lawrence Walsh, Jr.': {'party': 'D',
#   'district': 'House 86',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Capital Issues Subcommittee', '2643'),
#    ('Counties & Townships', '2348'),
#    ('Energy & Environment', '2355'),
#    ('Hydraulic Fracturing Subcommittee', '2634'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Public Utilities', '2311'),
#    ('Regulatory Matters Subcommittee', '2618'),
#    ('Renewable Initiatives Subcommittee', '2623'),
#    ('Utility Rate Regulations Subcommitt', '2606')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Tom Weber': {'party': 'R',
#   'district': 'House 64',
#   'committees': [('Appropriations-Human Services', '2295'),
#    ('Consumer Protection', '2298'),
#    ('Counties & Townships', '2348'),
#    ('Family Law Subcommittee', '2574'),
#    ('Judiciary - Civil', '2308'),
#    ('Labor & Commerce', '2309'),
#    ('Transportation: Regulation, Roads', '2350')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Grant Wehrli': {'party': 'R',
#   'district': 'House 41',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Appropriations-General Service', '2294'),
#    ('Business and Industry Regulations S', '2570'),
#    ('Cities & Villages', '2347'),
#    ('Commerce and Innovation Subcommitte', '2569'),
#    ('Executive', '2302'),
#    ('Job Growth, Preservation and Traini', '2566'),
#    ('Labor & Commerce', '2309'),
#    ('Local Government Subcommittee', '2596'),
#    ('Mental Health', '2389'),
#    ('Minority/Disadvantage Analysis Subc', '2568'),
#    ('Public Utilities', '2311'),
#    ('Special Investigating Comm.', '2646'),
#    ('Wage Policy and Study Subcommittee', '2567'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Emanuel Chris Welch': {'party': 'D',
#   'district': 'House 7',
#   'committees': [('Cities & Villages', '2347'),
#    ('Counties & Townships', '2348'),
#    ('Executive', '2302'),
#    ('Higher Education', '2305'),
#    ('Insurance', '2552'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Revenue & Finance', '2352')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'David A. Welter': {'party': 'R',
#   'district': 'House 75',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Appropriations-Public Safety', '2297'),
#    ('Counties & Townships', '2348'),
#    ('Energy & Environment', '2355'),
#    ('Public Utilities', '2311'),
#    ('Special Issues Subcommittee (TVS)', '2586'),
#    ('State Government Administration', '2313'),
#    ('Transportation: Vehicles & Safety', '2351')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Maurice A. West, II': {'party': 'D',
#   'district': 'House 67',
#   'committees': [('Appropriations-Higher Education', '2296'),
#    ('Higher Education', '2305'),
#    ('Judiciary - Criminal', '2362'),
#    ('Juvenile Justice and System Involve', '2603'),
#    ('Mental Health', '2389'),
#    ('Sex Offenses and Sex Offender Reg.', '2605')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Keith R. Wheeler': {'party': 'R',
#   'district': 'House 50',
#   'committees': [('Amusement & Online Gaming Sub', '2598'),
#    ('Broadband Access and IT Assurance', '2597'),
#    ('Business and Industry Regulations S', '2570'),
#    ('Commerce and Innovation Subcommitte', '2569'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Distributed Ledgers & Cryptocurrenc', '2599'),
#    ('Energy & Environment', '2355'),
#    ('Executive', '2302'),
#    ('Hydraulic Fracturing Subcommittee', '2634'),
#    ('Job Growth, Preservation and Traini', '2566'),
#    ('Labor & Commerce', '2309'),
#    ('Minority/Disadvantage Analysis Subc', '2568'),
#    ('Prescription Drug Affordability', '2553'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Public Utilities', '2311'),
#    ('Regulatory Matters Subcommittee', '2618'),
#    ('Renewable Initiatives Subcommittee', '2623'),
#    ('Revenue & Finance', '2352'),
#    ('Utility Rate Regulations Subcommitt', '2606'),
#    ('Wage Policy and Study Subcommittee', '2567'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Blaine Wilhour': {'party': 'R',
#   'district': 'House 107',
#   'committees': [('Administrative and Substantive', '2613'),
#    ('Adoption & Child Welfare', '2549'),
#    ('Judiciary - Criminal', '2362'),
#    ('Labor & Commerce', '2309'),
#    ('Personnel & Pensions', '2310'),
#    ('Personnel Code Subcommittee', '2562'),
#    ('Qualifications Challenge Committee', '2648'),
#    ('Sex Offenses and Sex Offender Reg.', '2605'),
#    ('Transportation: Vehicles & Safety', '2351')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Ann M. Williams': {'party': 'D',
#   'district': 'House 11',
#   'committees': [('Business and Industry Regulations S', '2570'),
#    ('Commerce and Innovation Subcommitte', '2569'),
#    ('Constitutional Law Subcommittee', '2572'),
#    ('Cybersecurity, Data Analytics, & IT', '2379'),
#    ('Election Process & Cybersecurity', '2645'),
#    ('Energy & Environment', '2355'),
#    ('Family Law Subcommittee', '2574'),
#    ('Judiciary - Civil', '2308'),
#    ('Labor & Commerce', '2309')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jawaharial Williams': {'party': 'D',
#   'district': 'House 10',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Financial Institutions', '2303'),
#    ('Public Utilities', '2311'),
#    ('Transportation: Vehicles & Safety', '2351')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Kathleen Willis': {'party': 'D',
#   'district': 'House 77',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Appropriations-Human Services', '2295'),
#    ('Cities & Villages', '2347'),
#    ('Counties & Townships', '2348'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Executive', '2302'),
#    ('Local Government Subcommittee', '2592'),
#    ('State Government Administration', '2313'),
#    ('Wages & Rates Subcommittee', '2633')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Patrick Windhorst': {'party': 'R',
#   'district': 'House 118',
#   'committees': [('Appropriations-Human Services', '2295'),
#    ('Criminal Administration and Enforce', '2601'),
#    ('Economic Opportunity & Equity', '2381'),
#    ('Higher Education', '2305'),
#    ('Human Services', '2306'),
#    ('Judiciary - Criminal', '2362'),
#    ('Mental Health', '2389'),
#    ('Qualifications Challenge Committee', '2648')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Lance Yednock': {'party': 'D',
#   'district': 'House 76',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Labor & Commerce', '2309'),
#    ('Transportation: Vehicles & Safety', '2351'),
#    ("Veterans' Affairs", '2315'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Sam Yingling': {'party': 'D',
#   'district': 'House 62',
#   'committees': [('Cities & Villages', '2347'),
#    ('Consolidation & Tax Subcommittee', '2593'),
#    ('Counties & Townships', '2348'),
#    ('Local Government Subcommittee', '2592'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Revenue & Finance', '2352'),
#    ('Transportation: Regulation, Roads', '2350')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Michael J. Zalewski': {'party': 'D',
#   'district': 'House 23',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Criminal Administration and Enforce', '2601'),
#    ('Health Care Licenses', '2349'),
#    ('Income Tax Subcommittee', '2588'),
#    ('Insurance', '2552'),
#    ('Judiciary - Criminal', '2362'),
#    ('Negotiations Subcommittee (NEGS)', '2594'),
#    ('Pension Reform Subcommittee', '2615'),
#    ('Personnel & Pensions', '2310'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Revenue & Finance', '2352'),
#    ('Sales, Amusement & Other Taxes', '2590'),
#    ('State Retirement System Subcommitte', '2563')],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Luis Arroyo': {'party': 'D',
#   'district': 'House 3',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Linda Chapa LaVia': {'party': 'D',
#   'district': 'House 83',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Melissa Conyears-Ervin': {'party': 'D',
#   'district': 'House 10',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Jerry Costello, II': {'party': 'D',
#   'district': 'House 116',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Lou Lang': {'party': 'D',
#   'district': 'House 16',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Robert Martwick': {'party': 'D',
#   'district': 'House 19',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Michael P. McAuliffe': {'party': 'R',
#   'district': 'House 20',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Christian L. Mitchell': {'party': 'D',
#   'district': 'House 26',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}}}

# %% [markdown]
# #### Bring in bill data

# %%
with open('bill_info.json') as f:
    bill_info = json.load(f)

# %% [markdown]
# #### Iterate through bills and update rep dictionary

# %%
for bill_num, bill_dict in bill_info.items():
    sponsors = []
    if bill_dict['senate sponsors']:
        sponsors.append(bill_dict['senate sponsors'][0])
    if bill_dict['house sponsors']:
        sponsors.append(bill_dict['house sponsors'][0])
    for sponsor in sponsors:    
        rep_info[sponsor]['bills']['ids'].append(bill_num)
        rep_info[sponsor]['bills']['count sponsored'] += 1
        if bill_dict['status'] == 'Passed and signed into law':
            rep_info[sponsor]['bills']['count passed'] += 1
        if bill_dict['committee']:
            topic = bill_dict['committee']
            if topic not in rep_info[sponsor]['bills']['topic counts']:
                rep_info[sponsor]['bills']['topic counts'][topic] = 0
            rep_info[sponsor]['bills']['topic counts'][topic] += 1

# %%
rep_info
# Out:
# {'Neil Anderson': {'party': 'R',
#   'district': 'Senate 36',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': ['SB0040',
#     'SB0058',
#     'SB0120',
#     'SB0148',
#     'SB0149',
#     'SB0160',
#     'SB0167',
#     'SB0173',
#     'SB0944',
#     'SB1042',
#     'SB1137',
#     'SB1138',
#     'SB1219',
#     'SB1435',
#     'SB1492',
#     'SB1815',
#     'SB1860',
#     'SB1870',
#     'SB1872',
#     'SB1873',
#     'SB1986',
#     'SB2117',
#     'SB2535',
#     'SB3033',
#     'SB3242',
#     'SB3444',
#     'SB3445',
#     'SB3695',
#     'SB3705',
#     'SB3706',
#     'SB3707',
#     'SB3708',
#     'HB0271',
#     'HB0822',
#     'HB0889',
#     'HB1554',
#     'HB1659',
#     'HB2397',
#     'HB2459',
#     'HB2669',
#     'HB2700',
#     'HB3610'],
#    'count sponsored': 42,
#    'count passed': 13,
#    'topic counts': {'Local Government': 1,
#     'Judiciary': 10,
#     'Licensed Activities': 3,
#     'Executive': 3,
#     'Energy and Public Utilities': 1,
#     'Transportation': 3,
#     'Agriculture': 1,
#     'Appropriations I': 1,
#     'Criminal Law': 1,
#     'Government Accountability and Pensions': 1,
#     'State Government Administration Committee': 2,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Insurance Committee': 1,
#     'Economic Opportunity & Equity Committee': 1,
#     'Transportation: Vehicles & Safety Committee': 2,
#     'Mental Health Committee': 1,
#     'Personnel & Pensions Committee': 1,
#     'Executive Committee': 1}}},
#  'Omar Aquino': {'party': 'D',
#   'district': 'Senate 2',
#   'committees': [('Appropriations I', '2317'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Executive', '2320'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Higher Education', '2333'),
#    ('Labor', '2334'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Sub. on Traffic Safety Systems', '2651'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Subcommittee on Charter Schools', '2555'),
#    ('Subcommittee on Procurement', '2650')],
#   'bills': {'ids': ['SB0079',
#     'SB0178',
#     'SB0412',
#     'SB0453',
#     'SB0656',
#     'SB1132',
#     'SB1264',
#     'SB1265',
#     'SB1266',
#     'SB1315',
#     'SB1316',
#     'SB1383',
#     'SB1384',
#     'SB1455',
#     'SB1584',
#     'SB1585',
#     'SB1586',
#     'SB1587',
#     'SB1734',
#     'SB1735',
#     'SB1736',
#     'SB1737',
#     'SB1780',
#     'SB1785',
#     'SB1786',
#     'SB1787',
#     'SB1792',
#     'SB1858',
#     'SB1859',
#     'SB2089',
#     'SB2090',
#     'SB2091',
#     'SB2092',
#     'SB2504',
#     'SB2519',
#     'SB2520',
#     'SB2936',
#     'SB3007',
#     'SB3009',
#     'SB3010',
#     'SB3126',
#     'SB3193',
#     'SB3194',
#     'SB3264',
#     'SB3324',
#     'SB3473',
#     'SB3571',
#     'SB3572',
#     'SB3573',
#     'SB3701',
#     'SB3702',
#     'SB3703',
#     'SB3713',
#     'HB1580',
#     'HB1690',
#     'HB2029',
#     'HB2170',
#     'HB2243',
#     'HB2272',
#     'HB2440',
#     'HB2455',
#     'HB2617',
#     'HB2662',
#     'HB2691',
#     'HB2838',
#     'HB3014',
#     'HB3082',
#     'HB3213',
#     'HB3222',
#     'HB3343',
#     'HB3405',
#     'HB3446',
#     'HB3593',
#     'HB3597',
#     'HB3606'],
#    'count sponsored': 75,
#    'count passed': 23,
#    'topic counts': {'Human Services': 3,
#     'Executive': 6,
#     'Revenue': 4,
#     'Government Accountability and Pensions': 6,
#     'Appropriations I': 2,
#     'Education': 1,
#     'Judiciary': 2,
#     'Transportation': 1,
#     'Financial Institutions': 1,
#     'Energy and Public Utilities': 1,
#     'Telecommunications and Information Technology': 1,
#     'Higher Education': 1,
#     'Local Government': 2,
#     'Licensed Activities': 2,
#     'Personnel & Pensions Committee': 9,
#     'Executive Committee': 2,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Revenue & Finance Committee': 1,
#     'Elementary & Secondary Education: Administration, Licensing & Charter School': 1,
#     'Higher Education Committee': 1,
#     'Labor & Commerce Committee': 2,
#     'State Government Administration Committee': 1,
#     'Human Services Committee': 1,
#     'Counties & Townships Committee': 1,
#     'Cybersecurity, Data Analytics, & IT Committee': 1}}},
#  'Jason A. Barickman': {'party': 'R',
#   'district': 'Senate 53',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Judiciary', '2345'),
#    ('Labor', '2334'),
#    ('Sub. on the Const.& Redistricting', '2625'),
#    ('Subcommittee on Gov. Operations', '2561'),
#    ('Subcommittee on Special Issues (CL)', '2609'),
#    ('Subcommittee on Special Issues (ED)', '2554')],
#   'bills': {'ids': ['SB0098',
#     'SB0117',
#     'SB0118',
#     'SB1227',
#     'SB1228',
#     'SB1229',
#     'SB1539',
#     'SB1540',
#     'SB1541',
#     'SB1542',
#     'SB1543',
#     'SB1644',
#     'SB1645',
#     'SB1646',
#     'SB1647',
#     'SB1648',
#     'SB1649',
#     'SB1767',
#     'SB1845',
#     'SB2134',
#     'SB2297',
#     'SB2518',
#     'SB2551',
#     'SB2888',
#     'SB3064',
#     'SB3149',
#     'SB3150',
#     'SB3224',
#     'SB3225',
#     'SB3314',
#     'SB3466',
#     'SB3467',
#     'SB3468',
#     'SB3469',
#     'SB3474',
#     'SB3475',
#     'SB3532',
#     'SB3591',
#     'SB3592',
#     'SB3593',
#     'SB3594',
#     'SB3595',
#     'SB3596',
#     'SB3597',
#     'SB3598',
#     'SB3599',
#     'SB3640',
#     'HB0092',
#     'HB0250',
#     'HB2383',
#     'HB2489',
#     'HB2583'],
#    'count sponsored': 52,
#    'count passed': 6,
#    'topic counts': {'Judiciary': 9,
#     'Education': 1,
#     'Executive': 5,
#     'Labor': 7,
#     'Transportation': 1,
#     'Revenue': 1,
#     'Executive Committee': 2,
#     'Revenue & Finance Committee': 1,
#     'Transportation: Vehicles & Safety Committee': 1,
#     'Counties & Townships Committee': 1}}},
#  'Christopher Belt': {'party': 'D',
#   'district': 'Senate 57',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Subcommittee on Special Issues (IN)', '2642')],
#   'bills': {'ids': ['SB1244',
#     'SB1418',
#     'SB1634',
#     'SB1744',
#     'SB1745',
#     'SB1746',
#     'SB1910',
#     'SB2152',
#     'SB2342',
#     'SB2343',
#     'SB2496',
#     'SB2497',
#     'SB2974',
#     'SB3003',
#     'SB3004',
#     'SB3026',
#     'SB3085',
#     'SB3214',
#     'SB3343',
#     'SB3374',
#     'SB3520',
#     'SB3521',
#     'SB3522',
#     'SB3605',
#     'SB3606',
#     'SB3817',
#     'SB3818',
#     'SB3819',
#     'SB3821',
#     'SB3977',
#     'HB0160',
#     'HB0456',
#     'HB1652',
#     'HB2433',
#     'HB2492',
#     'HB2497',
#     'HB2652',
#     'HB2656',
#     'HB3086',
#     'HB3247',
#     'HB3394',
#     'HB3511',
#     'HB3701'],
#    'count sponsored': 43,
#    'count passed': 15,
#    'topic counts': {'Veterans Affairs': 2,
#     'Criminal Law': 2,
#     'Agriculture': 1,
#     'Human Services': 1,
#     'Judiciary': 2,
#     'Education': 1,
#     'Government Accountability and Pensions': 1,
#     'Executive': 1,
#     'Transportation': 1,
#     'Public Health': 1,
#     'State Government': 3,
#     'Appropriations I': 2,
#     'Appropriations II': 1,
#     'Judiciary - Criminal Committee': 2,
#     'Executive Committee': 1,
#     'Health Care Licenses Committee': 1,
#     'Human Services Committee': 3,
#     'Transportation: Vehicles & Safety Committee': 1,
#     'Counties & Townships Committee': 1,
#     'Public Utilities Committee': 1,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Labor & Commerce Committee': 1,
#     'Health Care Availability & Accessibility Committee': 1}}},
#  'Scott M. Bennett': {'party': 'D',
#   'district': 'Senate 52',
#   'committees': [('Agriculture', '2316'),
#    ('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Higher Education', '2333'),
#    ('Labor', '2334'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('State Government', '2322'),
#    ('Subcommittee on Capital (AP)', '2591')],
#   'bills': {'ids': ['SB0009',
#     'SB0060',
#     'SB0211',
#     'SB0535',
#     'SB0671',
#     'SB1117',
#     'SB1329',
#     'SB1345',
#     'SB1468',
#     'SB1498',
#     'SB1499',
#     'SB1579',
#     'SB1638',
#     'SB1742',
#     'SB1761',
#     'SB1788',
#     'SB1803',
#     'SB1805',
#     'SB1817',
#     'SB1818',
#     'SB1920',
#     'SB1921',
#     'SB1922',
#     'SB1980',
#     'SB2027',
#     'SB2065',
#     'SB2098',
#     'SB2127',
#     'SB2133',
#     'SB2137',
#     'SB2460',
#     'SB2557',
#     'SB2765',
#     'SB2881',
#     'SB2905',
#     'SB2908',
#     'SB2933',
#     'SB2941',
#     'SB2942',
#     'SB3020',
#     'SB3157',
#     'SB3222',
#     'SB3329',
#     'SB3438',
#     'SB3448',
#     'SB3600',
#     'SB3614',
#     'SB3643',
#     'SB3679',
#     'SB3686',
#     'SB3692',
#     'SB3756',
#     'SB3759',
#     'SB3763',
#     'SB3781',
#     'SB3795',
#     'SB3865',
#     'HB0344',
#     'HB0357',
#     'HB2103',
#     'HB2252',
#     'HB2264',
#     'HB2737',
#     'HB3584',
#     'HB3667',
#     'HB3668'],
#    'count sponsored': 66,
#    'count passed': 14,
#    'topic counts': {'Environment and Conservation': 2,
#     'Appropriations I': 1,
#     'State Government': 2,
#     'Executive': 5,
#     'Transportation': 2,
#     'Criminal Law': 1,
#     'Veterans Affairs': 1,
#     'Education': 2,
#     'Higher Education': 3,
#     'Revenue': 4,
#     'Agriculture': 4,
#     'Appropriations II': 1,
#     'Judiciary': 2,
#     'Commerce and Economic Development': 1,
#     'Telecommunications and Information Technology': 1,
#     'Human Services Committee': 1,
#     'State Government Administration Committee': 2,
#     'Cities & Villages Committee': 1,
#     'Appropriations-General Services Committee': 1,
#     'Agriculture & Conservation Committee': 3,
#     'Judiciary - Criminal Committee': 1}}},
#  'Jennifer Bertino-Tarrant': {'party': 'D',
#   'district': 'Senate 49',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Subcommittee on Special Issues (ED)', '2554'),
#    ('Transportation', '2327')],
#   'bills': {'ids': ['SB0028',
#     'SB0059',
#     'SB0069',
#     'SB0084',
#     'SB0112',
#     'SB0140',
#     'SB0209',
#     'SB0216',
#     'SB0451',
#     'SB0460',
#     'SB0538',
#     'SB0654',
#     'SB0662',
#     'SB1457',
#     'SB1458',
#     'SB1512',
#     'SB1513',
#     'SB1705',
#     'SB1706',
#     'SB1707',
#     'SB1757',
#     'SB2044',
#     'SB2045',
#     'SB2260',
#     'SB2283',
#     'SB2324',
#     'SB2474',
#     'SB2800',
#     'SB2971',
#     'SB2972',
#     'SB3038',
#     'SB3200',
#     'SB3201',
#     'SB3202',
#     'SB3482',
#     'SB3483',
#     'SB3814',
#     'SB3815',
#     'SB3816',
#     'HB0190',
#     'HB0356',
#     'HB0423',
#     'HB1472',
#     'HB2087',
#     'HB2189',
#     'HB2605',
#     'HB2676',
#     'HB3191',
#     'HB3498',
#     'HB3503',
#     'HB3576',
#     'HB3687'],
#    'count sponsored': 52,
#    'count passed': 13,
#    'topic counts': {'Education': 7,
#     'Criminal Law': 1,
#     'Appropriations I': 1,
#     'Executive': 6,
#     'Revenue': 4,
#     'State Government': 1,
#     'Judiciary': 2,
#     'Higher Education': 1,
#     'Telecommunications and Information Technology': 1,
#     'Elementary & Secondary Education: Administration, Licensing & Charter School': 2,
#     'Executive Committee': 1,
#     'Personnel & Pensions Committee': 1,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Insurance Committee': 2,
#     'Health Care Licenses Committee': 2,
#     'Judiciary - Criminal Committee': 3}}},
#  'William E. Brady': {'party': 'R',
#   'district': 'Senate 44',
#   'committees': [('Committee of the Whole', '2332'), ('Executive', '2320')],
#   'bills': {'ids': ['SB0785',
#     'SB0786',
#     'SB0787',
#     'SB0788',
#     'SB0789',
#     'SB0790',
#     'SB0791',
#     'SB0792',
#     'SB0793',
#     'SB0794',
#     'SB0795',
#     'SB0796',
#     'SB0797',
#     'SB0798',
#     'SB0799',
#     'SB0800',
#     'SB0801',
#     'SB0802',
#     'SB0803',
#     'SB0804',
#     'SB0805',
#     'SB0806',
#     'SB0807',
#     'SB0808',
#     'SB0809',
#     'SB0810',
#     'SB0811',
#     'SB0812',
#     'SB0813',
#     'SB0814',
#     'SB0815',
#     'SB0816',
#     'SB0817',
#     'SB0818',
#     'SB0819',
#     'SB0820',
#     'SB0821',
#     'SB0822',
#     'SB0823',
#     'SB0824',
#     'SB0825',
#     'SB0826',
#     'SB0827',
#     'SB0828',
#     'SB0829',
#     'SB0830',
#     'SB0831',
#     'SB0832',
#     'SB0833',
#     'SB0834',
#     'SB0835',
#     'SB0836',
#     'SB0837',
#     'SB0838',
#     'SB0839',
#     'SB0840',
#     'SB0841',
#     'SB0842',
#     'SB0843',
#     'SB0844',
#     'SB0845',
#     'SB0846',
#     'SB0847',
#     'SB0848',
#     'SB0849',
#     'SB0850',
#     'SB0851',
#     'SB0852',
#     'SB0853',
#     'SB0854',
#     'SB0855',
#     'SB0856',
#     'SB0857',
#     'SB0858',
#     'SB0859',
#     'SB0860',
#     'SB0861',
#     'SB0862',
#     'SB0863',
#     'SB0864',
#     'SB0865',
#     'SB0866',
#     'SB0867',
#     'SB0868',
#     'SB0869',
#     'SB0870',
#     'SB0871',
#     'SB0872',
#     'SB0873',
#     'SB0874',
#     'SB0875',
#     'SB0876',
#     'SB0877',
#     'SB0878',
#     'SB0879',
#     'SB0880',
#     'SB0881',
#     'SB0882',
#     'SB0883',
#     'SB0884',
#     'SB0885',
#     'SB0886',
#     'SB0887',
#     'SB0888',
#     'SB0889',
#     'SB0890',
#     'SB0891',
#     'SB0892',
#     'SB0893',
#     'SB0894',
#     'SB0895',
#     'SB0897',
#     'SB0898',
#     'SB0910',
#     'SB0911',
#     'SB0912',
#     'SB0913',
#     'SB0914',
#     'SB0916',
#     'SB0917',
#     'SB0918',
#     'SB0919',
#     'SB0920',
#     'SB0921',
#     'SB0922',
#     'SB0923',
#     'SB0924',
#     'SB0925',
#     'SB0926',
#     'SB0930',
#     'SB0931',
#     'SB0932',
#     'SB0933',
#     'SB0934',
#     'SB0935',
#     'SB0936',
#     'SB0937',
#     'SB0938',
#     'SB0939',
#     'SB0940',
#     'SB0941',
#     'SB0942',
#     'SB0943',
#     'SB0948',
#     'SB0949',
#     'SB0950',
#     'SB0951',
#     'SB0952',
#     'SB0953',
#     'SB0954',
#     'SB0955',
#     'SB0956',
#     'SB0957',
#     'SB0959',
#     'SB0960',
#     'SB0961',
#     'SB0962',
#     'SB0963',
#     'SB0964',
#     'SB0965',
#     'SB0966',
#     'SB0967',
#     'SB0968',
#     'SB0969',
#     'SB0970',
#     'SB0971',
#     'SB0972',
#     'SB0973',
#     'SB0974',
#     'SB0975',
#     'SB0976',
#     'SB0977',
#     'SB0978',
#     'SB0979',
#     'SB0980',
#     'SB0983',
#     'SB0984',
#     'SB0985',
#     'SB0987',
#     'SB0988',
#     'SB0989',
#     'SB0990',
#     'SB0991',
#     'SB0992',
#     'SB0993',
#     'SB0994',
#     'SB0995',
#     'SB0996',
#     'SB0997',
#     'SB0998',
#     'SB0999',
#     'SB1000',
#     'SB1001',
#     'SB1002',
#     'SB1003',
#     'SB1004',
#     'SB1005',
#     'SB1006',
#     'SB1008',
#     'SB1009',
#     'SB1010',
#     'SB1011',
#     'SB1012',
#     'SB1013',
#     'SB1014',
#     'SB1015',
#     'SB1016',
#     'SB1017',
#     'SB1018',
#     'SB1019',
#     'SB1020',
#     'SB1021',
#     'SB1022',
#     'SB1023',
#     'SB1024',
#     'SB1025',
#     'SB1026',
#     'SB1027',
#     'SB1028',
#     'SB1029',
#     'SB1031',
#     'SB1032',
#     'SB1033',
#     'SB1034',
#     'SB1036',
#     'SB1037',
#     'SB1038',
#     'SB1039',
#     'SB1040',
#     'SB1044',
#     'SB1045',
#     'SB1046',
#     'SB1047',
#     'SB1048',
#     'SB1049',
#     'SB1051',
#     'SB1052',
#     'SB1053',
#     'SB1054',
#     'SB1056',
#     'SB1057',
#     'SB1062',
#     'SB1063',
#     'SB1064',
#     'SB1065',
#     'SB1067',
#     'SB1068',
#     'SB1069',
#     'SB1070',
#     'SB1071',
#     'SB1072',
#     'SB1073',
#     'SB1074',
#     'SB1075',
#     'SB1076',
#     'SB1077',
#     'SB1078',
#     'SB1079',
#     'SB1081',
#     'SB1082',
#     'SB1083',
#     'SB1084',
#     'SB1085',
#     'SB1086',
#     'SB1087',
#     'SB1088',
#     'SB1089',
#     'SB1091',
#     'SB1092',
#     'SB1093',
#     'SB1094',
#     'SB1095',
#     'SB1096',
#     'SB1097',
#     'SB1098',
#     'SB1099',
#     'SB1100',
#     'SB1101',
#     'SB1102',
#     'SB1103',
#     'SB1104',
#     'SB1433',
#     'SB1434',
#     'SB1727',
#     'SB2018',
#     'SB2046',
#     'SB2568',
#     'SB2569',
#     'SB2570',
#     'SB2571',
#     'SB2572',
#     'SB2573',
#     'SB2574',
#     'SB2575',
#     'SB2576',
#     'SB2577',
#     'SB2578',
#     'SB2579',
#     'SB2580',
#     'SB2581',
#     'SB2582',
#     'SB2583',
#     'SB2584',
#     'SB2585',
#     'SB2586',
#     'SB2587',
#     'SB2588',
#     'SB2589',
#     'SB2590',
#     'SB2591',
#     'SB2592',
#     'SB2593',
#     'SB2594',
#     'SB2595',
#     'SB2596',
#     'SB2597',
#     'SB2598',
#     'SB2599',
#     'SB2600',
#     'SB2601',
#     'SB2602',
#     'SB2603',
#     'SB2604',
#     'SB2605',
#     'SB2606',
#     'SB2607',
#     'SB2608',
#     'SB2609',
#     'SB2610',
#     'SB2611',
#     'SB2612',
#     'SB2613',
#     'SB2614',
#     'SB2615',
#     'SB2616',
#     'SB2617',
#     'SB2618',
#     'SB2619',
#     'SB2620',
#     'SB2621',
#     'SB2622',
#     'SB2623',
#     'SB2624',
#     'SB2625',
#     'SB2626',
#     'SB2627',
#     'SB2628',
#     'SB2629',
#     'SB2630',
#     'SB2631',
#     'SB2632',
#     'SB2633',
#     'SB2634',
#     'SB2635',
#     'SB2636',
#     'SB2637',
#     'SB2638',
#     'SB2639',
#     'SB2640',
#     'SB2641',
#     'SB2642',
#     'SB2643',
#     'SB2644',
#     'SB2645',
#     'SB2646',
#     'SB2647',
#     'SB2648',
#     'SB2649',
#     'SB2650',
#     'SB2651',
#     'SB2652',
#     'SB2653',
#     'SB2654',
#     'SB2655',
#     'SB2656',
#     'SB2657',
#     'SB2658',
#     'SB2659',
#     'SB2660',
#     'SB2661',
#     'SB2662',
#     'SB2663',
#     'SB2664',
#     'SB2665',
#     'SB2666',
#     'SB2667',
#     'SB2668',
#     'SB2669',
#     'SB2670',
#     'SB2671',
#     'SB2672',
#     'SB2673',
#     'SB2674',
#     'SB2675',
#     'SB2676',
#     'SB2677',
#     'SB2678',
#     'SB2679',
#     'SB2680',
#     'SB2681',
#     'SB2682',
#     'SB2683',
#     'SB2684',
#     'SB2685',
#     'SB2686',
#     'SB2687',
#     'SB2688',
#     'SB2689',
#     'SB2690',
#     'SB2691',
#     'SB2692',
#     'SB2693',
#     'SB2694',
#     'SB2695',
#     'SB2696',
#     'SB2697',
#     'SB2698',
#     'SB2699',
#     'SB2700',
#     'SB2701',
#     'SB2702',
#     'SB2703',
#     'SB2704',
#     'SB2705',
#     'SB2706',
#     'SB2707',
#     'SB2708',
#     'SB2709',
#     'SB2710',
#     'SB2711',
#     'SB2712',
#     'SB2713',
#     'SB2714',
#     'SB2715',
#     'SB2716',
#     'SB2717',
#     'SB2718',
#     'SB2719',
#     'SB2720',
#     'SB2721',
#     'SB2722',
#     'SB2723',
#     'SB2724',
#     'SB2725',
#     'SB2726',
#     'SB2727',
#     'SB2728',
#     'SB2729',
#     'SB2730',
#     'SB2731',
#     'SB2732',
#     'SB2733',
#     'SB2734',
#     'SB2735',
#     'SB2736',
#     'SB2737',
#     'SB2738',
#     'SB2977',
#     'SB3039',
#     'SB3040',
#     'SB3041',
#     'SB3042',
#     'SB3148',
#     'SB3680'],
#    'count sponsored': 464,
#    'count passed': 0,
#    'topic counts': {'Executive': 452,
#     'Judiciary': 2,
#     'Revenue': 5,
#     'Education': 2}}},
#  'Melinda Bush': {'party': 'D',
#   'district': 'Senate 31',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Environment and Conservation', '2344'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Revenue', '2326'),
#    ('Sub. on Interscholastic Athletics', '2556'),
#    ('Sub. on Tax Exemptions and Credits', '2616'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Transportation', '2327')],
#   'bills': {'ids': ['SB0025',
#     'SB0029',
#     'SB0030',
#     'SB0031',
#     'SB0032',
#     'SB0033',
#     'SB0034',
#     'SB0035',
#     'SB0036',
#     'SB0037',
#     'SB0038',
#     'SB0074',
#     'SB0075',
#     'SB0556',
#     'SB0557',
#     'SB0730',
#     'SB0764',
#     'SB1113',
#     'SB1114',
#     'SB1119',
#     'SB1120',
#     'SB1121',
#     'SB1122',
#     'SB1218',
#     'SB1296',
#     'SB1322',
#     'SB1323',
#     'SB1324',
#     'SB1325',
#     'SB1363',
#     'SB1364',
#     'SB1426',
#     'SB1507',
#     'SB1588',
#     'SB1694',
#     'SB1770',
#     'SB1828',
#     'SB1829',
#     'SB1854',
#     'SB1905',
#     'SB1942',
#     'SB2341',
#     'SB2486',
#     'SB2487',
#     'SB2488',
#     'SB2494',
#     'SB2513',
#     'SB2514',
#     'SB2515',
#     'SB2516',
#     'SB3397',
#     'SB3398',
#     'SB3399',
#     'SB3400',
#     'SB3401',
#     'SB3402',
#     'SB3403',
#     'SB3404',
#     'SB3405',
#     'SB3406',
#     'SB3407',
#     'SB3408',
#     'SB3409',
#     'SB3410',
#     'SB3420',
#     'SB3421',
#     'SB3422',
#     'SB3423',
#     'SB3424',
#     'SB3425',
#     'SB3426',
#     'SB3441',
#     'SB3574',
#     'SB3575',
#     'SB3576',
#     'SB3577',
#     'SB3578',
#     'SB3579',
#     'SB3580',
#     'SB3581',
#     'SB3582',
#     'SB3583',
#     'SB3584',
#     'SB3585',
#     'SB3586',
#     'SB3587',
#     'SB3588',
#     'SB3589',
#     'SB3590',
#     'SB3646',
#     'SB3647',
#     'SB3648',
#     'SB3649',
#     'SB3650',
#     'SB3651',
#     'SB3652',
#     'SB3653',
#     'SB3654',
#     'SB3655',
#     'SB3656',
#     'SB3657',
#     'SB3658',
#     'SB3659',
#     'SB3660',
#     'SB3661',
#     'SB3832',
#     'SB3833',
#     'SB3834',
#     'HB0840',
#     'HB0921',
#     'HB0925',
#     'HB2124',
#     'HB2296',
#     'HB2601',
#     'HB2643',
#     'HB3092',
#     'HB3501',
#     'HB3590',
#     'HB3652'],
#    'count sponsored': 119,
#    'count passed': 20,
#    'topic counts': {'Judiciary': 5,
#     'Revenue': 4,
#     'Executive': 11,
#     'Insurance': 1,
#     'Energy and Public Utilities': 1,
#     'Government Accountability and Pensions': 1,
#     'Labor': 1,
#     'Local Government': 4,
#     'Education': 1,
#     'Public Health': 2,
#     'Environment and Conservation': 3,
#     'Criminal Law': 2,
#     'State Government': 1,
#     'Energy & Environment Committee': 2,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 2,
#     'Revenue & Finance Committee': 2,
#     'State Government Administration Committee': 1,
#     'Judiciary - Civil Committee': 1,
#     'Labor & Commerce Committee': 1,
#     'Agriculture & Conservation Committee': 1,
#     'Executive Committee': 1}}},
#  'Cristina Castro': {'party': 'D',
#   'district': 'Senate 22',
#   'committees': [('Appropriations I', '2317'),
#    ('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Labor', '2334'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Revenue', '2326'),
#    ('Subcommittee on Special Issues (RE)', '2653'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': ['SB0062',
#     'SB0073',
#     'SB0076',
#     'SB0132',
#     'SB0163',
#     'SB0223',
#     'SB0224',
#     'SB0455',
#     'SB0638',
#     'SB1191',
#     'SB1196',
#     'SB1197',
#     'SB1290',
#     'SB1300',
#     'SB1313',
#     'SB1330',
#     'SB1331',
#     'SB1332',
#     'SB1466',
#     'SB1509',
#     'SB1717',
#     'SB1718',
#     'SB1719',
#     'SB1720',
#     'SB1721',
#     'SB1722',
#     'SB1797',
#     'SB1906',
#     'SB1907',
#     'SB1908',
#     'SB2049',
#     'SB2132',
#     'SB2258',
#     'SB2268',
#     'SB2272',
#     'SB2273',
#     'SB2287',
#     'SB2456',
#     'SB2491',
#     'SB2531',
#     'SB2533',
#     'SB2545',
#     'SB2563',
#     'SB2921',
#     'SB2922',
#     'SB2969',
#     'SB2999',
#     'SB3000',
#     'SB3001',
#     'SB3023',
#     'SB3024',
#     'SB3078',
#     'SB3079',
#     'SB3080',
#     'SB3081',
#     'SB3082',
#     'SB3083',
#     'SB3084',
#     'SB3215',
#     'SB3216',
#     'SB3223',
#     'SB3308',
#     'SB3386',
#     'SB3414',
#     'SB3415',
#     'SB3416',
#     'SB3470',
#     'SB3742',
#     'SB3743',
#     'SB3744',
#     'SB3745',
#     'SB3746',
#     'SB3823',
#     'SB3824',
#     'SB3836',
#     'SB3853',
#     'SB3854',
#     'SB3897',
#     'HB0120',
#     'HB0137',
#     'HB0252',
#     'HB0834',
#     'HB0854',
#     'HB1553',
#     'HB2129',
#     'HB2156',
#     'HB2399',
#     'HB2502',
#     'HB2627',
#     'HB2802',
#     'HB3534'],
#    'count sponsored': 91,
#    'count passed': 20,
#    'topic counts': {'Judiciary': 6,
#     'Commerce and Economic Development': 2,
#     'Licensed Activities': 2,
#     'Local Government': 3,
#     'Human Services': 3,
#     'Executive': 5,
#     'Government Accountability and Pensions': 4,
#     'Financial Institutions': 2,
#     'Labor': 1,
#     'Transportation': 1,
#     'Telecommunications and Information Technology': 3,
#     'State Government': 1,
#     'Revenue': 5,
#     'Higher Education': 2,
#     'Public Health': 1,
#     'Energy and Public Utilities': 1,
#     'Education': 1,
#     'Veterans Affairs': 1,
#     'Executive Committee': 2,
#     'Labor & Commerce Committee': 3,
#     'Adoption & Child Welfare Committee': 1,
#     'Cities & Villages Committee': 1,
#     'Consumer Protection Committee': 1,
#     'State Government Administration Committee': 2,
#     'Personnel & Pensions Committee': 1,
#     'Judiciary - Criminal Committee': 1,
#     'Elementary & Secondary Education: Administration, Licensing & Charter School': 1}}},
#  'Jacqueline Y. Collins': {'party': 'D',
#   'district': 'Senate 16',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Financial Institutions', '2321'),
#    ('Insurance', '2323'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Transportation', '2327')],
#   'bills': {'ids': ['SB0138',
#     'SB0197',
#     'SB0482',
#     'SB1289',
#     'SB1510',
#     'SB1511',
#     'SB1583',
#     'SB1821',
#     'SB2482',
#     'SB3125',
#     'SB3158',
#     'SB3195',
#     'SB3339',
#     'SB3479',
#     'SB3490',
#     'SB3491',
#     'SB3503',
#     'SB3623',
#     'SB3700',
#     'SB3841',
#     'SB3842',
#     'SB3868',
#     'SB3869',
#     'HB0001',
#     'HB0002',
#     'HB0003',
#     'HB0005',
#     'HB0018',
#     'HB0026',
#     'HB0029',
#     'HB0051',
#     'HB0157',
#     'HB0331',
#     'HB2118',
#     'HB2265',
#     'HB2438',
#     'HB2444',
#     'HB2897',
#     'HB3393',
#     'HB4276'],
#    'count sponsored': 40,
#    'count passed': 16,
#    'topic counts': {'Financial Institutions': 2,
#     'Education': 1,
#     'Executive': 1,
#     'Human Services': 1,
#     'Criminal Law': 5,
#     'Transportation': 1,
#     'Judiciary': 1,
#     'Labor': 1,
#     'Health Care Availability & Accessibility Committee': 4,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 2,
#     'Appropriations-Higher Education Committee': 1,
#     'Judiciary - Civil Committee': 1,
#     'Judiciary - Criminal Committee': 2,
#     'Transportation: Vehicles & Safety Committee': 1,
#     'Appropriations-Human Services Committee': 1,
#     'Health Care Licenses Committee': 1,
#     'Mental Health Committee': 1,
#     'Financial Institutions Committee': 1}}},
#  'Rachelle Crowe': {'party': 'D',
#   'district': 'Senate 56',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Criminal Law', '2342'),
#    ('Judiciary', '2345'),
#    ('Labor', '2334'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Sub. on the Const.& Redistricting', '2625'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Subcommittee on Tort Reform', '2628'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': ['SB0185',
#     'SB0215',
#     'SB0221',
#     'SB0414',
#     'SB0447',
#     'SB0584',
#     'SB0766',
#     'SB1230',
#     'SB1317',
#     'SB1450',
#     'SB1522',
#     'SB1565',
#     'SB1622',
#     'SB1625',
#     'SB1643',
#     'SB1666',
#     'SB1749',
#     'SB1750',
#     'SB1834',
#     'SB1835',
#     'SB1882',
#     'SB1883',
#     'SB2037',
#     'SB2262',
#     'SB2464',
#     'SB2965',
#     'SB3128',
#     'SB3129',
#     'SB3152',
#     'SB3153',
#     'SB3166',
#     'SB3167',
#     'SB3235',
#     'SB3236',
#     'SB3344',
#     'SB3345',
#     'SB3427',
#     'SB3439',
#     'SB3534',
#     'SB3604',
#     'SB3625',
#     'SB3626',
#     'SB3627',
#     'SB3628',
#     'SB3629',
#     'SB3630',
#     'SB3631',
#     'SB3632',
#     'SB3633',
#     'SB3634',
#     'SB3644',
#     'SB3690',
#     'SB3755',
#     'SB3768',
#     'SB3813',
#     'HB0038',
#     'HB0347',
#     'HB2119',
#     'HB2211',
#     'HB2239',
#     'HB2303',
#     'HB2862',
#     'HB3469',
#     'HB3471',
#     'HB3509',
#     'HB3677',
#     'HB3902'],
#    'count sponsored': 67,
#    'count passed': 13,
#    'topic counts': {'Education': 1,
#     'Judiciary': 7,
#     'Executive': 6,
#     'Criminal Law': 8,
#     'Higher Education': 1,
#     'State Government': 2,
#     'Revenue': 1,
#     'Licensed Activities': 3,
#     'Agriculture': 1,
#     'Public Health': 1,
#     'Human Services': 1,
#     'Judiciary - Criminal Committee': 1,
#     'Judiciary - Civil Committee': 2,
#     'Transportation: Vehicles & Safety Committee': 1,
#     'Higher Education Committee': 1,
#     'Cities & Villages Committee': 1,
#     'Insurance Committee': 2,
#     'Revenue & Finance Committee': 1}}},
#  'Thomas Cullerton': {'party': 'D',
#   'district': 'Senate 23',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('State Government', '2322'),
#    ('Sub. on Utility Rate Regulations', '2631'),
#    ('Transportation', '2327'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': ['SB0142',
#     'SB0150',
#     'SB0151',
#     'SB0218',
#     'SB0219',
#     'SB0411',
#     'SB0532',
#     'SB0640',
#     'SB0658',
#     'SB1127',
#     'SB1128',
#     'SB1129',
#     'SB1130',
#     'SB1141',
#     'SB1214',
#     'SB1215',
#     'SB1216',
#     'SB1217',
#     'SB1362',
#     'SB1496',
#     'SB1531',
#     'SB1560',
#     'SB1561',
#     'SB1562',
#     'SB1629',
#     'SB1651',
#     'SB1652',
#     'SB1675',
#     'SB1695',
#     'SB1838',
#     'SB1839',
#     'SB1897',
#     'SB1898',
#     'SB2105',
#     'SB2330',
#     'SB2495',
#     'SB3088',
#     'SB3189',
#     'SB3232',
#     'SB3515',
#     'SB3820',
#     'HB0013',
#     'HB0105',
#     'HB0303',
#     'HB0313',
#     'HB0823',
#     'HB1561',
#     'HB2215',
#     'HB2540',
#     'HB2830',
#     'HB2832',
#     'HB2841',
#     'HB3053',
#     'HB3172',
#     'HB3198',
#     'HB3358',
#     'HB3424',
#     'HB3531',
#     'HB3536'],
#    'count sponsored': 59,
#    'count passed': 20,
#    'topic counts': {'Education': 2,
#     'Higher Education': 3,
#     'Judiciary': 4,
#     'Criminal Law': 2,
#     'Executive': 5,
#     'Veterans Affairs': 2,
#     'Transportation': 4,
#     'Public Health': 1,
#     'Local Government': 4,
#     'Revenue': 1,
#     'Labor': 1,
#     'Licensed Activities': 3,
#     'Agriculture': 1,
#     'Health Care Licenses Committee': 2,
#     'Executive Committee': 2,
#     'Personnel & Pensions Committee': 1,
#     'State Government Administration Committee': 1,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Labor & Commerce Committee': 2,
#     'Judiciary - Civil Committee': 3,
#     'Elementary & Secondary Education: Administration, Licensing & Charter School': 1,
#     'Revenue & Finance Committee': 1,
#     "Veterans' Affairs Committee": 1,
#     'Human Services Committee': 1,
#     'Transportation: Vehicles & Safety Committee': 1}}},
#  'Bill Cunningham': {'party': 'D',
#   'district': 'Senate 18',
#   'committees': [('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Executive', '2320'),
#    ('Executive Appointments', '2319'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323')],
#   'bills': {'ids': ['SB0018',
#     'SB0247',
#     'SB0248',
#     'SB0249',
#     'SB0416',
#     'SB0663',
#     'SB0715',
#     'SB1256',
#     'SB1258',
#     'SB1259',
#     'SB1260',
#     'SB1261',
#     'SB1262',
#     'SB1263',
#     'SB1381',
#     'SB1382',
#     'SB1462',
#     'SB1590',
#     'SB1732',
#     'SB1747',
#     'SB1781',
#     'SB1954',
#     'SB2051',
#     'SB2084',
#     'SB2240',
#     'SB2277',
#     'SB2281',
#     'SB2298',
#     'SB2331',
#     'SB2558',
#     'SB2792',
#     'SB2793',
#     'SB2978',
#     'SB3055',
#     'SB3056',
#     'SB3074',
#     'SB3075',
#     'SB3118',
#     'SB3119',
#     'SB3204',
#     'SB3205',
#     'SB3206',
#     'SB3207',
#     'SB3208',
#     'SB3209',
#     'SB3210',
#     'SB3211',
#     'SB3212',
#     'SB3263',
#     'SB3286',
#     'SB3287',
#     'SB3288',
#     'SB3289',
#     'SB3290',
#     'SB3502',
#     'SB3603',
#     'SB3612',
#     'SB3613',
#     'SB3615',
#     'SB3772',
#     'SB3774',
#     'SB3775',
#     'SB3776',
#     'SB3777',
#     'SB3778',
#     'SB3837',
#     'HB1579',
#     'HB2222',
#     'HB2266',
#     'HB2275',
#     'HB2470',
#     'HB2576',
#     'HB2682',
#     'HB2763',
#     'HB2767',
#     'HB2961',
#     'HB2988'],
#    'count sponsored': 77,
#    'count passed': 10,
#    'topic counts': {'Executive': 15,
#     'Environment and Conservation': 1,
#     'Public Health': 2,
#     'Transportation': 1,
#     'Judiciary': 1,
#     'Criminal Law': 2,
#     'Labor': 1,
#     'Government Accountability and Pensions': 1,
#     'Energy and Public Utilities': 3,
#     'Licensed Activities': 1,
#     'Higher Education': 1,
#     'Education': 1,
#     'Revenue': 1,
#     'Judiciary - Criminal Committee': 2,
#     'State Government Administration Committee': 1,
#     'Labor & Commerce Committee': 2,
#     'Personnel & Pensions Committee': 1,
#     'Human Services Committee': 1,
#     'Counties & Townships Committee': 1}}},
#  'John F. Curran': {'party': 'R',
#   'district': 'Senate 41',
#   'committees': [('Appropriations II', '2329'),
#    ('Assignments', '2341'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Local Government', '2324'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Capital (AP)', '2591'),
#    ('Transportation', '2327')],
#   'bills': {'ids': ['SB0026',
#     'SB0161',
#     'SB0199',
#     'SB0200',
#     'SB0927',
#     'SB1050',
#     'SB1149',
#     'SB1273',
#     'SB1580',
#     'SB1581',
#     'SB1582',
#     'SB1776',
#     'SB1824',
#     'SB1852',
#     'SB1853',
#     'SB1855',
#     'SB1856',
#     'SB1877',
#     'SB1928',
#     'SB1929',
#     'SB2048',
#     'SB2264',
#     'SB2265',
#     'SB3546',
#     'SB3547',
#     'SB3548',
#     'SB3549',
#     'SB3550',
#     'SB3551',
#     'SB3552',
#     'SB3553',
#     'SB3554',
#     'SB3555',
#     'SB3556',
#     'SB3557',
#     'SB3558',
#     'SB3559',
#     'SB3560',
#     'SB3561',
#     'SB3562',
#     'SB3563',
#     'SB3564',
#     'SB3565',
#     'SB3566',
#     'SB3567',
#     'SB3568',
#     'SB3569',
#     'SB3570',
#     'SB3855',
#     'SB3856',
#     'SB3857',
#     'SB3858',
#     'SB3859',
#     'HB1583',
#     'HB2073',
#     'HB2512',
#     'HB2562',
#     'HB2582',
#     'HB2613',
#     'HB3263',
#     'HB3888'],
#    'count sponsored': 61,
#    'count passed': 10,
#    'topic counts': {'Criminal Law': 3,
#     'Judiciary': 3,
#     'Executive': 2,
#     'Local Government': 4,
#     'Government Accountability and Pensions': 1,
#     'Revenue': 1,
#     'Environment and Conservation': 2,
#     'Licensed Activities': 1,
#     'Judiciary - Criminal Committee': 1,
#     'Cities & Villages Committee': 1,
#     'Higher Education Committee': 1,
#     'Health Care Licenses Committee': 1,
#     'Personnel & Pensions Committee': 1,
#     'Energy & Environment Committee': 1}}},
#  'Donald P. DeWitte': {'party': 'R',
#   'district': 'Senate 33',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Local Government', '2324'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Pension Investments Special Com. On', '2617'),
#    ('Revenue', '2326'),
#    ('Sub. on Tax Exemptions and Credits', '2616'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Subcommittee on Local Policies', '2636'),
#    ('Subcommittee on Special Issues (RE)', '2653'),
#    ('Telecommunications & InfoTechnology', '2375'),
#    ('Transportation', '2327')],
#   'bills': {'ids': ['SB0986',
#     'SB1041',
#     'SB1043',
#     'SB1201',
#     'SB1202',
#     'SB1203',
#     'SB1204',
#     'SB1205',
#     'SB1206',
#     'SB1207',
#     'SB1208',
#     'SB1209',
#     'SB1210',
#     'SB1282',
#     'SB1406',
#     'SB1535',
#     'SB1549',
#     'SB1550',
#     'SB1809',
#     'SB2241',
#     'SB2266',
#     'SB2741',
#     'SB2742',
#     'SB2756',
#     'SB2782',
#     'SB2783',
#     'SB2784',
#     'SB2785',
#     'SB2786',
#     'SB2787',
#     'SB2788',
#     'SB2789',
#     'SB2790',
#     'SB2791',
#     'SB3162',
#     'SB3163',
#     'SB3164',
#     'SB3165',
#     'SB3433',
#     'SB3492',
#     'SB3687',
#     'SB3688',
#     'HB2528',
#     'HB3274',
#     'HB3390'],
#    'count sponsored': 45,
#    'count passed': 3,
#    'topic counts': {'Executive': 5,
#     'Judiciary': 2,
#     'Criminal Law': 1,
#     'Agriculture': 1,
#     'Appropriations I': 1,
#     'Revenue': 2,
#     'Higher Education': 1,
#     'State Government': 1,
#     'Appropriations II': 1,
#     'Local Government': 1,
#     'Judiciary - Civil Committee': 1,
#     'Human Services Committee': 1,
#     'Labor & Commerce Committee': 1}}},
#  'Laura Ellman': {'party': 'D',
#   'district': 'Senate 21',
#   'committees': [('Agriculture', '2316'),
#    ('Appropriations I', '2317'),
#    ('Committee of the Whole', '2332'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Higher Education', '2333'),
#    ('Subcommittee on Special Issues (EP)', '2630'),
#    ('Veterans Affairs', '2374')],
#   'bills': {'ids': ['SB0459',
#     'SB0725',
#     'SB1155',
#     'SB1156',
#     'SB1157',
#     'SB1167',
#     'SB1168',
#     'SB1169',
#     'SB1170',
#     'SB1171',
#     'SB1172',
#     'SB1173',
#     'SB1174',
#     'SB1176',
#     'SB1177',
#     'SB1178',
#     'SB1346',
#     'SB1347',
#     'SB1416',
#     'SB1417',
#     'SB1631',
#     'SB1710',
#     'SB1740',
#     'SB1794',
#     'SB1795',
#     'SB1896',
#     'SB2122',
#     'SB2768',
#     'SB2961',
#     'SB2975',
#     'SB3154',
#     'SB3387',
#     'SB3388',
#     'SB3389',
#     'SB3390',
#     'SB3391',
#     'SB3471',
#     'SB3472',
#     'SB3711',
#     'SB3712',
#     'HB0833',
#     'HB0961',
#     'HB3068',
#     'HB3320',
#     'HB3481'],
#    'count sponsored': 45,
#    'count passed': 8,
#    'topic counts': {'Executive': 5,
#     'Higher Education': 3,
#     'Revenue': 1,
#     'State Government': 1,
#     'Energy and Public Utilities': 3,
#     'Insurance': 1,
#     'Criminal Law': 1,
#     'Financial Institutions': 1,
#     'Transportation': 1,
#     'Environment and Conservation': 1,
#     'Education': 1,
#     'Public Health': 1,
#     'Judiciary': 1,
#     'Revenue & Finance Committee': 1,
#     'Executive Committee': 1,
#     'Energy & Environment Committee': 2,
#     'Insurance Committee': 1}}},
#  'Sara Feigenholtz': {'party': 'D',
#   'district': 'House 12',
#   'committees': [],
#   'bills': {'ids': ['SB0054',
#     'SB0054',
#     'SB0191',
#     'SB0193',
#     'SB0391',
#     'SB0458',
#     'SB1116',
#     'SB1135',
#     'SB1572',
#     'SB1715',
#     'SB1778',
#     'SB2559',
#     'SB2757',
#     'SB2760',
#     'SB3130',
#     'SB3131',
#     'SB3132',
#     'SB3133',
#     'SB3134',
#     'SB3135',
#     'SB3136',
#     'SB3137',
#     'SB3138',
#     'SB3139',
#     'SB3140',
#     'SB3141',
#     'SB3142',
#     'SB3143',
#     'SB3144',
#     'SB3145',
#     'SB3146',
#     'SB3147',
#     'SB3335',
#     'SB3373',
#     'SB3523',
#     'SB3524',
#     'SB3525',
#     'SB3526',
#     'SB3527',
#     'SB3528',
#     'SB3529',
#     'SB3530',
#     'SB3531',
#     'SB3729',
#     'SB3730',
#     'SB3731',
#     'SB3828',
#     'SB3829',
#     'SB3830',
#     'SB3831',
#     'HB1439',
#     'HB1460',
#     'HB1461',
#     'HB1462',
#     'HB1463',
#     'HB1585',
#     'HB2153',
#     'HB2154',
#     'HB2168',
#     'HB2169',
#     'HB2259',
#     'HB2260',
#     'HB2261',
#     'HB2262',
#     'HB2571',
#     'HB2572',
#     'HB2637',
#     'HB2690',
#     'HB3267',
#     'HB3268',
#     'HB3587'],
#    'count sponsored': 71,
#    'count passed': 11,
#    'topic counts': {'Executive': 6,
#     'Human Services': 7,
#     'Judiciary': 5,
#     'Licensed Activities': 2,
#     'Agriculture': 1,
#     'Government Accountability and Pensions': 1,
#     'Insurance': 1,
#     'Appropriations I': 2,
#     'Transportation': 1,
#     'Executive Committee': 8,
#     'Judiciary - Civil Committee': 1,
#     'Adoption & Child Welfare Committee': 3,
#     'Human Services Committee': 2,
#     'Revenue & Finance Committee': 1,
#     'Appropriations-Human Services Committee': 5,
#     'State Government Administration Committee': 1}}},
#  'Laura Fine': {'party': 'D',
#   'district': 'Senate 9',
#   'committees': [('Appropriations II', '2329'),
#    ('Committee of the Whole', '2332'),
#    ('Environment and Conservation', '2344'),
#    ('Human Services', '2330'),
#    ('Insurance', '2323'),
#    ('Local Government', '2324'),
#    ('Public Health', '2337'),
#    ('Public Safety Spec. Committee On', '2647'),
#    ('Subcommittee on Local Policies', '2636'),
#    ('Subcommittee on Special Issues (IN)', '2642')],
#   'bills': {'ids': ['SB0191',
#     'SB0192',
#     'SB0198',
#     'SB0239',
#     'SB0246',
#     'SB0665',
#     'SB1116',
#     'SB1150',
#     'SB1184',
#     'SB1185',
#     'SB1193',
#     'SB1194',
#     'SB1195',
#     'SB1225',
#     'SB1238',
#     'SB1243',
#     'SB1352',
#     'SB1419',
#     'SB1526',
#     'SB1527',
#     'SB1528',
#     'SB1640',
#     'SB1679',
#     'SB1790',
#     'SB1791',
#     'SB2023',
#     'SB2085',
#     'SB2086',
#     'SB2087',
#     'SB2088',
#     'SB2255',
#     'SB2311',
#     'SB2340',
#     'SB2561',
#     'SB2740',
#     'SB2747',
#     'SB2771',
#     'SB2781',
#     'SB2954',
#     'SB3037',
#     'SB3054',
#     'SB3071',
#     'SB3072',
#     'SB3217',
#     'SB3226',
#     'SB3227',
#     'SB3266',
#     'SB3267',
#     'SB3297',
#     'SB3299',
#     'SB3313',
#     'SB3377',
#     'SB3378',
#     'SB3411',
#     'SB3431',
#     'SB3447',
#     'SB3493',
#     'SB3545',
#     'SB3610',
#     'SB3611',
#     'SB3638',
#     'SB3639',
#     'SB3677',
#     'SB3678',
#     'SB3732',
#     'SB3766',
#     'SB3767',
#     'HB0122',
#     'HB0253',
#     'HB0471',
#     'HB2096',
#     'HB2174',
#     'HB2209',
#     'HB2238',
#     'HB2287',
#     'HB2578',
#     'HB2846',
#     'HB2854',
#     'HB3097',
#     'HB3113',
#     'HB3115',
#     'HB3331',
#     'HB3427',
#     'HB3482',
#     'HB3483'],
#    'count sponsored': 85,
#    'count passed': 19,
#    'topic counts': {'Human Services': 10,
#     'Judiciary': 6,
#     'Transportation': 1,
#     'Criminal Law': 4,
#     'Local Government': 1,
#     'Executive': 1,
#     'Labor': 1,
#     'Environment and Conservation': 3,
#     'Insurance': 6,
#     'Financial Institutions': 1,
#     'Commerce and Economic Development': 1,
#     'State Government': 2,
#     'Licensed Activities': 1,
#     'Government Accountability and Pensions': 1,
#     'Executive Committee': 2,
#     'Labor & Commerce Committee': 2,
#     'Prescription Drug Affordability & Accessibility Committee': 2,
#     'Revenue & Finance Committee': 2,
#     'State Government Administration Committee': 1,
#     'Judiciary - Civil Committee': 1,
#     'Insurance Committee': 2,
#     'Cities & Villages Committee': 1,
#     'Human Services Committee': 2,
#     'Public Utilities Committee': 1}}},
#  'Dale Fowler': {'party': 'R',
#   'district': 'Senate 59',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Higher Education', '2333'),
#    ('Insurance', '2323'),
#    ('Licensed Activities', '2325'),
#    ('Opioid Crisis Abatement Spec. Com.', '2644'),
#    ('Subcommittee on Capital (TR)', '2583'),
#    ('Transportation', '2327')],
#   'bills': {'ids': ['SB0168',
#     'SB0194',
#     'SB1055',
#     'SB1490',
#     'SB2303',
#     'SB2774',
#     'SB2943',
#     'SB2944',
#     'SB2945',
#     'SB2963',
#     'SB3029',
#     'SB3030',
#     'SB3031',
#     'SB3032',
#     'SB3063',
#     'SB3230',
#     'SB3309',
#     'HB0210',
#     'HB2505'],
#    'count sponsored': 19,
#    'count passed': 3,
#    'topic counts': {'Judiciary': 4,
#     'Government Accountability and Pensions': 1,
#     'Executive': 1,
#     'Agriculture': 3,
#     'Transportation': 2,
#     'Revenue': 2,
#     'State Government Administration Committee': 2}}},
#  'Ann Gillespie': {'party': 'D',
#   'district': 'Senate 27',
#   'committees': [('Appropriations I', '2317'),
#    ('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Government Accountability/Pensions', '2373'),
#    ('Insurance', '2323'),
#    ('Judiciary', '2345'),
#    ('Oversight Medicaid Mang. Care, Spec', '2611'),
#    ('Subcommittee on Civil Rights', '2626'),
#    ('Subcommittee on Firearms', '2627')],
#   'bills': {'ids': ['SB0230',
#     'SB0650',
#     'SB1242',
#     'SB1295',
#     'SB1479',
#     'SB1591',
#     'SB1888',
#     'SB1919',
#     'SB2024',
#     'SB2279',
#     'SB2315',
#     'SB2468',
#     'SB2469',
#     'SB2746',
#     'SB2890',
#     'SB2938',
#     'SB2940',
#     'SB3013',
#     'SB3014',
#     'SB3049',
#     'SB3161',
#     'SB3198',
#     'SB3726',
#     'SB3727',
#     'SB3728',
#     'SB3780',
#     'SB3849',
#     'HB2076',
#     'HB2868',
#     'HB3554'],
#    'count sponsored': 30,
#    'count passed': 7,
#    'topic counts': {'Executive': 3,
#     'Judiciary': 3,
#     'Revenue': 2,
#     'Licensed Activities': 1,
#     'Commerce and Economic Development': 1,
#     'Labor': 1,
#     'Education': 2,
#     'Insurance': 2,
#     'Energy & Environment Committee': 1,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Health Care Licenses Committee': 1}}},
#  'Suzy Glowiak Hilton': {'party': 'D',
#   'district': 'Senate 24',
#   'committees': [('Commerce and Economic Development', '2358'),
#    ('Committee of the Whole', '2332'),
#    ('Education', '2318'),
#    ('Energy and Public Utilities', '2343'),
#    ('Insurance', '2323'),
#    ('Labor', '2334'),
#    ('Local Government', '2324'),
#    ('Sub. on Utility Rate Regulations', '2631')],
#   'bills': {'ids': ['SB0727',
#     'SB1294',
#     'SB1430',
#     'SB1624',
#     'SB1654',
#     'SB1711',
#     'SB1726',
#     'SB1810',
#     'SB1909',
#     'SB2094',
#     'SB2326',
#     'SB2463',
#     'SB2472',
#     'SB2548',
#     'SB2909',
#     'SB2946',
#     'SB3008',
#     'SB3036',
#     'SB3298',
#     'SB3302',
#     'SB3412',
#     'SB3720',
#     'SB3754',
#     'HB2818',
#     'HB2983',
#     'HB3101'],
#    'count sponsored': 26,
#    'count passed': 9,
#    'topic counts': {'Executive': 1,
#     'Criminal Law': 1,
#     'Telecommunications and Information Technology': 1,
#     'Appropriations I': 1,
#     'Public Health': 4,
#     'Government Accountability and Pensions': 1,
#     'Agriculture': 1,
#     'Higher Education': 1,
#     'Licensed Activities': 1,
#     'Commerce and Economic Development': 1,
#     'State Government': 1,
#     'Judiciary': 1,
#     'Local Government': 1,
#     'Judiciary - Criminal Committee': 1,
#     'Human Services Committee': 1,
#     'Labor & Commerce Committee': 1}}},
#  'Don Harmon': {'party': 'D',
#   'district': 'Senate 39',
#   'committees': [('Committee of the Whole', '2332'),
#    ('Executive', '2320'),
#    ('Judiciary', '2345'),
#    ('Subcommittee on Business Entities', '2624')],
#   'bills': {'ids': ['SB0002',
#     'SB0003',
#     'SB0004',
#     'SB0005',
#     'SB0006',
#     'SB0011',
#     'SB0012',
#     'SB0014',
#     'SB0015',
#     'SB0016',
#     'SB0017',
#     'SB0019',
#     'SB0020',
#     'SB0042',
#     'SB0103',
#     'SB0105',
#     'SB0147',
#     'SB0227',
#     'SB0228',
#     'SB0260',
#     'SB0261',
#     'SB0263',
#     'SB0264',
#     'SB0265',
#     'SB0266',
#     'SB0267',
#     'SB0268',
#     'SB0269',
#     'SB0270',
#     'SB0271',
#     'SB0272',
#     'SB0273',
#     'SB0274',
#     'SB0275',
#     'SB0276',
#     'SB0277',
#     'SB0278',
#     'SB0279',
#     'SB0280',
#     'SB0281',
#     'SB0282',
#     'SB0283',
#     'SB0284',
#     'SB0285',
#     'SB0286',
#     'SB0287',
#     'SB0288',
#     'SB0289',
#     'SB0290',
#     'SB0291',
#     'SB0292',
#     'SB0293',
#     'SB0294',
#     'SB0295',
#     'SB0296',
#     'SB0297',
#     'SB0298',
#     'SB0299',
#     'SB0300',
#     'SB0301',
#     'SB0302',
#     'SB0303',
#     'SB0304',
#     'SB0305',
#     'SB0306',
#     'SB0307',
#     'SB0308',
#     'SB0309',
#     'SB0310',
#     'SB0311',
#     'SB0312',
#     'SB0313',
#     'SB0314',
#     'SB0315',
#     'SB0316',
#     'SB0317',
#     'SB0318',
#     'SB0319',
#     'SB0320',
#     'SB0321',
#     'SB0322',
#     'SB0323',
#     'SB0324',
#     'SB0325',
#     'SB0326',
#     'SB0327',
#     'SB0328',
#     'SB0329',
#     'SB0330',
#     'SB0331',
#     'SB0332',
#     'SB0333',
#     'SB0334',
#     'SB0335',
#     'SB0336',
#     'SB0337',
#     'SB0338',
#     'SB0339',
#     'SB0340',
#     'SB0341',
#     'SB0342',
#     'SB0343',
#     'SB0344',
#     'SB0345',
#     'SB0346',
#     'SB0347',
#     'SB0348',
#     'SB0349',
#     'SB0350',
#     'SB0351',
#     'SB0352',
#     'SB0353',
#     'SB0354',
#     'SB0355',
#     'SB0356',
#     'SB0357',
#     'SB0358',
#     'SB0359',
#     'SB0360',
#     'SB0361',
#     'SB0362',
#     'SB0363',
#     'SB0364',
#     'SB0365',
#     'SB0366',
#     'SB0367',
#     'SB0368',
#     'SB0369',
#     'SB0370',
#     'SB0371',
#     'SB0372',
#     'SB0373',
#     'SB0374',
#     'SB0375',
#     'SB0376',
#     'SB0377',
#     'SB0378',
#     'SB0379',
#     'SB0380',
#     'SB0381',
#     'SB0382',
#     'SB0383',
#     'SB0384',
#     'SB0385',
#     'SB0386',
#     'SB0387',
#     'SB0388',
#     'SB0389',
#     'SB0390',
#     'SB0392',
#     'SB0393',
#     'SB0394',
#     'SB0395',
#     'SB0400',
#     'SB0401',
#     'SB0402',
#     'SB0403',
#     'SB0404',
#     'SB0405',
#     'SB0406',
#     'SB0407',
#     'SB0408',
#     'SB0409',
#     'SB0410',
#     'SB0415',
#     'SB0417',
#     'SB0418',
#     'SB0419',
#     'SB0420',
# ...
#     'SB0718',
#     'SB0730',
#     'SB0731',
#     'SB0780',
#     'SB1571',
#     'SB1864',
#     'SB1868',
#     'SB2559',
#     'HB1471',
#     'HB1582',
#     'HB1604',
#     'HB2134',
#     'HB2296',
#     'HB2522',
#     'HB2703',
#     'HB2784',
#     'HB2785',
#     'HB2820',
#     'HB2979',
#     'HB2988',
#     'HB2989',
#     'HB2990',
#     'HB3335',
#     'HB3337',
#     'HB3351',
#     'HB3550',
#     'HB3624',
#     'HB4500',
#     'HB4827',
#     'HB4909',
#     'HB5115',
#     'HB5495',
#     'HB5496',
#     'HB5497',
#     'HB5529',
#     'HB5550',
#     'HB5551',
#     'HB5552',
#     'HB5637'],
#    'count sponsored': 42,
#    'count passed': 13,
#    'topic counts': {'Labor': 1,
#     'Environment and Conservation': 1,
#     'Judiciary': 4,
#     'Executive': 4,
#     'Public Health': 1,
#     'Judiciary - Civil Committee': 2,
#     'Cybersecurity, Data Analytics, & IT Committee': 3,
#     'Judiciary - Criminal Committee': 1,
#     'Energy & Environment Committee': 2,
#     'Executive Committee': 6,
#     'Cities & Villages Committee': 1,
#     'Counties & Townships Committee': 1,
#     'Revenue & Finance Committee': 1,
#     'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1}}},
#  'Jawaharial Williams': {'party': 'D',
#   'district': 'House 10',
#   'committees': [('Appropriations-Capital', '2550'),
#    ('Financial Institutions', '2303'),
#    ('Public Utilities', '2311'),
#    ('Transportation: Vehicles & Safety', '2351')],
#   'bills': {'ids': ['SB0657', 'HB4423', 'HB5346', 'HB5347'],
#    'count sponsored': 4,
#    'count passed': 1,
#    'topic counts': {'Executive': 1}}},
#  'Kathleen Willis': {'party': 'D',
#   'district': 'House 77',
#   'committees': [('Adoption & Child Welfare', '2549'),
#    ('Appropriations-Human Services', '2295'),
#    ('Cities & Villages', '2347'),
#    ('Counties & Townships', '2348'),
#    ('Elem Sec Ed: School Curric Policies', '2300'),
#    ('Executive', '2302'),
#    ('Local Government Subcommittee', '2592'),
#    ('State Government Administration', '2313'),
#    ('Wages & Rates Subcommittee', '2633')],
#   'bills': {'ids': ['SB0111',
#     'SB0218',
#     'SB0219',
#     'SB0246',
#     'SB0531',
#     'SB0640',
#     'SB0659',
#     'SB1588',
#     'SB1698',
#     'SB1829',
#     'SB1966',
#     'HB0096',
#     'HB0105',
#     'HB0123',
#     'HB0271',
#     'HB0273',
#     'HB0350',
#     'HB0823',
#     'HB0841',
#     'HB1583',
#     'HB1584',
#     'HB2089',
#     'HB2096',
#     'HB2174',
#     'HB2253',
#     'HB2254',
#     'HB2353',
#     'HB2471',
#     'HB2473',
#     'HB2488',
#     'HB2502',
#     'HB2532',
#     'HB2709',
#     'HB2710',
#     'HB3027',
#     'HB3420',
#     'HB3846',
#     'HB3934',
#     'HB3960',
#     'HB3989',
#     'HB4043',
#     'HB4044',
#     'HB4184',
#     'HB4324',
#     'HB4325',
#     'HB4479',
#     'HB4511',
#     'HB4663',
#     'HB4692',
#     'HB4701',
#     'HB4725',
#     'HB4814',
#     'HB4867',
#     'HB4873',
#     'HB4922',
#     'HB5157',
#     'HB5465'],
#    'count sponsored': 57,
#    'count passed': 10,
#    'topic counts': {'Insurance': 1,
#     'Judiciary': 3,
#     'Criminal Law': 2,
#     'Local Government': 1,
#     'Executive': 3,
#     'Government Accountability and Pensions': 1,
#     'Executive Committee': 9,
#     'State Government Administration Committee': 2,
#     'Insurance Committee': 1,
#     'Personnel & Pensions Committee': 2,
#     'Health Care Licenses Committee': 2,
#     'Judiciary - Criminal Committee': 5,
#     'Prescription Drug Affordability & Accessibility Committee': 1,
#     'Cities & Villages Committee': 1,
#     'Human Services Committee': 2,
#     'Judiciary - Civil Committee': 1,
#     'Appropriations-Human Services Committee': 2,
#     'Labor & Commerce Committee': 1,
#     'Revenue & Finance Committee': 1}}},
#  'Patrick Windhorst': {'party': 'R',
#   'district': 'House 118',
#   'committees': [('Appropriations-Human Services', '2295'),
#    ('Criminal Administration and Enforce', '2601'),
#    ('Economic Opportunity & Equity', '2381'),
#    ('Higher Education', '2305'),
#    ('Human Services', '2306'),
#    ('Judiciary - Criminal', '2362'),
#    ('Mental Health', '2389'),
#    ('Qualifications Challenge Committee', '2648')],
#   'bills': {'ids': ['SB1490',
#     'SB2303',
#     'HB0339',
#     'HB0340',
#     'HB0368',
#     'HB0911',
#     'HB0912',
#     'HB0913',
#     'HB2057',
#     'HB2058',
#     'HB2066',
#     'HB2308',
#     'HB2309',
#     'HB2384',
#     'HB2507',
#     'HB2965',
#     'HB3173',
#     'HB3174',
#     'HB3175',
#     'HB3176',
#     'HB4389',
#     'HB4390',
#     'HB4391',
#     'HB4392',
#     'HB4393',
#     'HB4394',
#     'HB4395',
#     'HB4396',
#     'HB4397',
#     'HB4398',
#     'HB4447',
#     'HB4448',
#     'HB4449',
#     'HB4450',
#     'HB4747',
#     'HB4767',
#     'HB5154',
#     'HB5295',
#     'HB5296'],
#    'count sponsored': 39,
#    'count passed': 2,
#    'topic counts': {'Agriculture': 1,
#     'Transportation': 1,
#     'Judiciary - Criminal Committee': 13,
#     'Executive Committee': 4,
#     'Revenue & Finance Committee': 1,
#     'Human Services Committee': 2}}},
#  'Lance Yednock': {'party': 'D',
#   'district': 'House 76',
#   'committees': [('Agriculture & Conservation', '2331'),
#    ('Labor & Commerce', '2309'),
#    ('Transportation: Vehicles & Safety', '2351'),
#    ("Veterans' Affairs", '2315'),
#    ('Workforce Development Subcommittee', '2565')],
#   'bills': {'ids': ['SB1343',
#     'SB1474',
#     'HB0138',
#     'HB0357',
#     'HB2215',
#     'HB2216',
#     'HB2789',
#     'HB2790',
#     'HB2791',
#     'HB3451',
#     'HB3452',
#     'HB3453',
#     'HB3454',
#     'HB3455',
#     'HB3456',
#     'HB3457',
#     'HB3458',
#     'HB3459',
#     'HB3460',
#     'HB3461',
#     'HB3474',
#     'HB3563',
#     'HB5128',
#     'HB5179',
#     'HB5180',
#     'HB5196',
#     'HB5258',
#     'HB5480'],
#    'count sponsored': 28,
#    'count passed': 3,
#    'topic counts': {'Transportation': 1,
#     'Labor': 1,
#     'Executive Committee': 1,
#     'State Government Administration Committee': 1,
#     'Labor & Commerce Committee': 2,
#     'Revenue & Finance Committee': 5,
#     'Agriculture & Conservation Committee': 2,
#     'Insurance Committee': 2,
#     'Judiciary - Criminal Committee': 5,
#     'Human Services Committee': 1,
#     'Health Care Licenses Committee': 1}}},
#  'Sam Yingling': {'party': 'D',
#   'district': 'House 62',
#   'committees': [('Cities & Villages', '2347'),
#    ('Consolidation & Tax Subcommittee', '2593'),
#    ('Counties & Townships', '2348'),
#    ('Local Government Subcommittee', '2592'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Revenue & Finance', '2352'),
#    ('Transportation: Regulation, Roads', '2350')],
#   'bills': {'ids': ['SB0556',
#     'SB1114',
#     'SB1215',
#     'SB1236',
#     'SB1461',
#     'HB0377',
#     'HB0457',
#     'HB1496',
#     'HB1497',
#     'HB1498',
#     'HB1499',
#     'HB1500',
#     'HB1501',
#     'HB1502',
#     'HB1503',
#     'HB1504',
#     'HB1505',
#     'HB1506',
#     'HB1507',
#     'HB1508',
#     'HB1509',
#     'HB1510',
#     'HB1511',
#     'HB1512',
#     'HB1513',
#     'HB1514',
#     'HB1515',
#     'HB1516',
#     'HB1517',
#     'HB1518',
#     'HB1519',
#     'HB1520',
#     'HB1521',
#     'HB1522',
#     'HB1523',
#     'HB1524',
#     'HB1525',
#     'HB1526',
#     'HB1527',
#     'HB1528',
#     'HB1529',
#     'HB1530',
#     'HB1531',
#     'HB1532',
#     'HB1533',
#     'HB1534',
#     'HB1535',
#     'HB1536',
#     'HB1537',
#     'HB1538',
#     'HB1539',
#     'HB1540',
#     'HB1541',
#     'HB1542',
#     'HB1543',
#     'HB1544',
#     'HB1545',
#     'HB1546',
#     'HB1547',
#     'HB1548',
#     'HB1549',
#     'HB1550',
#     'HB2206',
#     'HB2207',
#     'HB2208',
#     'HB2209',
#     'HB2210',
#     'HB2211',
#     'HB2212',
#     'HB2213',
#     'HB2214',
#     'HB2320',
#     'HB2899',
#     'HB3589',
#     'HB3590',
#     'HB3591',
#     'HB3593',
#     'HB3594',
#     'HB3595',
#     'HB3596',
#     'HB3597',
#     'HB3598',
#     'HB3599',
#     'HB3600',
#     'HB3601',
#     'HB3602',
#     'HB3603',
#     'HB4172',
#     'HB4173',
#     'HB4174',
#     'HB4175',
#     'HB4176',
#     'HB4177',
#     'HB4178',
#     'HB4179',
#     'HB4180',
#     'HB4181',
#     'HB4182',
#     'HB4183',
#     'HB4185',
#     'HB4186',
#     'HB4187',
#     'HB4188',
#     'HB4189',
#     'HB4190',
#     'HB4191',
#     'HB4192',
#     'HB4193',
#     'HB4194',
#     'HB4195',
#     'HB4196',
#     'HB4197',
#     'HB4198',
#     'HB4199',
#     'HB4200',
#     'HB4201',
#     'HB4202',
#     'HB4203',
#     'HB4204',
#     'HB4205',
#     'HB4206',
#     'HB4207',
#     'HB4208',
#     'HB4209',
#     'HB5181'],
#    'count sponsored': 125,
#    'count passed': 4,
#    'topic counts': {'Executive': 1,
#     'Local Government': 2,
#     'Government Accountability and Pensions': 1,
#     'Education': 1,
#     'Executive Committee': 57,
#     'Counties & Townships Committee': 7,
#     'Judiciary - Civil Committee': 1,
#     'Revenue & Finance Committee': 8,
#     'Public Utilities Committee': 2,
#     'State Government Administration Committee': 4}}},
#  'Michael J. Zalewski': {'party': 'D',
#   'district': 'House 23',
#   'committees': [('Appropriations-General Service', '2294'),
#    ('Criminal Administration and Enforce', '2601'),
#    ('Health Care Licenses', '2349'),
#    ('Income Tax Subcommittee', '2588'),
#    ('Insurance', '2552'),
#    ('Judiciary - Criminal', '2362'),
#    ('Negotiations Subcommittee (NEGS)', '2594'),
#    ('Pension Reform Subcommittee', '2615'),
#    ('Personnel & Pensions', '2310'),
#    ('Property Tax Subcommittee', '2589'),
#    ('Revenue & Finance', '2352'),
#    ('Sales, Amusement & Other Taxes', '2590'),
#    ('State Retirement System Subcommitte', '2563')],
#   'bills': {'ids': ['SB0119',
#     'SB0687',
#     'SB1140',
#     'SB1257',
#     'SB1456',
#     'SB1582',
#     'SB1881',
#     'SB2099',
#     'SB2104',
#     'SB2128',
#     'SB2325',
#     'HB0102',
#     'HB0200',
#     'HB0745',
#     'HB0826',
#     'HB1260',
#     'HB1270',
#     'HB1271',
#     'HB1459',
#     'HB2071',
#     'HB2166',
#     'HB2573',
#     'HB2574',
#     'HB2575',
#     'HB2576',
#     'HB2577',
#     'HB2578',
#     'HB2579',
#     'HB2580',
#     'HB2581',
#     'HB2582',
#     'HB2673',
#     'HB2674',
#     'HB2676',
#     'HB2677',
#     'HB2678',
#     'HB2679',
#     'HB2680',
#     'HB2681',
#     'HB2682',
#     'HB2823',
#     'HB2824',
#     'HB2825',
#     'HB2826',
#     'HB2827',
#     'HB2853',
#     'HB2919',
#     'HB2947',
#     'HB3308',
#     'HB3312',
#     'HB3313',
#     'HB3314',
#     'HB3315',
#     'HB3354',
#     'HB3409',
#     'HB3411',
#     'HB3412',
#     'HB3588',
#     'HB3625',
#     'HB3713',
#     'HB3968',
#     'HB4475',
#     'HB4503',
#     'HB4518',
#     'HB4554',
#     'HB4555',
#     'HB4556',
#     'HB4557',
#     'HB4572',
#     'HB4573',
#     'HB4758',
#     'HB4813',
#     'HB4840',
#     'HB4889',
#     'HB4890',
#     'HB5041',
#     'HB5320',
#     'HB5592',
#     'HB5593',
#     'HB5594',
#     'HB5595'],
#    'count sponsored': 81,
#    'count passed': 15,
#    'topic counts': {'Revenue': 3,
#     'Executive': 3,
#     'Government Accountability and Pensions': 1,
#     'Local Government': 1,
#     'State Government': 1,
#     'Commerce and Economic Development': 1,
#     'Licensed Activities': 1,
#     'Executive Committee': 19,
#     'Transportation: Vehicles & Safety Committee': 3,
#     'Revenue & Finance Committee': 14,
#     'Labor & Commerce Committee': 1,
#     'Personnel & Pensions Committee': 6,
#     'Health Care Licenses Committee': 1,
#     'Transportation: Regulation, Roads & Bridges Committee': 1,
#     'Energy & Environment Committee': 1}}},
#  'Luis Arroyo': {'party': 'D',
#   'district': 'House 3',
#   'committees': [],
#   'bills': {'ids': ['SB1636',
#     'HB0058',
#     'HB0124',
#     'HB0143',
#     'HB2624',
#     'HB2625',
#     'HB2626',
#     'HB2713',
#     'HB2916',
#     'HB3046',
#     'HB3047',
#     'HB3419',
#     'HB3421',
#     'HB3441',
#     'HB3443',
#     'HB3444',
#     'HB3626',
#     'HB3844',
#     'HB3895',
#     'HB3911'],
#    'count sponsored': 20,
#    'count passed': 3,
#    'topic counts': {'Judiciary': 1,
#     'Executive Committee': 9,
#     'Transportation: Regulation, Roads & Bridges Committee': 1,
#     'Public Utilities Committee': 1,
#     'Transportation: Vehicles & Safety Committee': 1,
#     'Judiciary - Criminal Committee': 2,
#     'State Government Administration Committee': 1,
#     'Appropriations-Higher Education Committee': 1}}},
#  'Linda Chapa LaVia': {'party': 'D',
#   'district': 'House 83',
#   'committees': [],
#   'bills': {'ids': ['HB0923',
#     'HB2225',
#     'HB2245',
#     'HB2246',
#     'HB2607',
#     'HB2608',
#     'HB2711',
#     'HB2712',
#     'HB2933',
#     'HB3236',
#     'HB3238'],
#    'count sponsored': 11,
#    'count passed': 0,
#    'topic counts': {'Executive Committee': 7,
#     'Public Utilities Committee': 3,
#     'Agriculture & Conservation Committee': 1}}},
#  'Melissa Conyears-Ervin': {'party': 'D',
#   'district': 'House 10',
#   'committees': [],
#   'bills': {'ids': ['HB0931',
#     'HB0932',
#     'HB2275',
#     'HB3413',
#     'HB3422',
#     'HB3423',
#     'HB3567',
#     'HB3568'],
#    'count sponsored': 8,
#    'count passed': 0,
#    'topic counts': {'Elementary & Secondary Education: School Curriculum & Policies  Committee': 1,
#     'Judiciary - Criminal Committee': 1,
#     'Labor & Commerce Committee': 1,
#     'Revenue & Finance Committee': 2,
#     'State Government Administration Committee': 1,
#     'Appropriations-Human Services Committee': 1,
#     'Child Care Accessibility & Early Childhood Education Committee': 1}}},
#  'Jerry Costello, II': {'party': 'D',
#   'district': 'House 116',
#   'committees': [],
#   'bills': {'ids': ['SB1842',
#     'HB2787',
#     'HB2788',
#     'HB3158',
#     'HB3159',
#     'HB3160',
#     'HB3161',
#     'HB3162',
#     'HB3163',
#     'HB3164',
#     'HB3165',
#     'HB3166',
#     'HB3167',
#     'HB3448',
#     'HB3449',
#     'HB3450',
#     'HB3615',
#     'HB3616',
#     'HB3617',
#     'HB3618',
#     'HB3619',
#     'HB3621',
#     'HB3622',
#     'HB3665',
#     'HB3666',
#     'HB3667',
#     'HB3668',
#     'HB3669',
#     'HB3670',
#     'HB3815'],
#    'count sponsored': 30,
#    'count passed': 2,
#    'topic counts': {'Judiciary': 1,
#     'Executive Committee': 5,
#     'Human Services Committee': 1,
#     'Judiciary - Criminal Committee': 10,
#     'Revenue & Finance Committee': 3,
#     'Transportation: Vehicles & Safety Committee': 1,
#     'Appropriations-Public Safety Committee': 1,
#     'Personnel & Pensions Committee': 1,
#     'Agriculture & Conservation Committee': 4,
#     'Appropriations-General Services Committee': 2}}},
#  'Lou Lang': {'party': 'D',
#   'district': 'House 16',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}},
#  'Robert Martwick': {'party': 'D',
#   'district': 'House 19',
#   'committees': [],
#   'bills': {'ids': ['SB0181',
#     'SB1264',
#     'SB1265',
#     'SB1273',
#     'SB1464',
#     'SB1601',
#     'SB1787',
#     'SB2030',
#     'SB2060',
#     'HB0226',
#     'HB0811',
#     'HB0812',
#     'HB0827',
#     'HB0828',
#     'HB0832',
#     'HB0850',
#     'HB1580',
#     'HB1646',
#     'HB1647',
#     'HB1648',
#     'HB1649',
#     'HB1650',
#     'HB1651',
#     'HB2240',
#     'HB2241',
#     'HB2268',
#     'HB2269',
#     'HB2270',
#     'HB2271',
#     'HB2440',
#     'HB2441',
#     'HB2451',
#     'HB2452',
#     'HB2455',
#     'HB2617',
#     'HB2619',
#     'HB2661',
#     'HB2662',
#     'HB2701',
#     'HB2704',
#     'HB2903',
#     'HB2904',
#     'HB2905',
#     'HB2906',
#     'HB2907',
#     'HB2908',
#     'HB2910',
#     'HB2911',
#     'HB2978',
#     'HB3013',
#     'HB3082',
#     'HB3605',
#     'HB3606',
#     'HB3660'],
#    'count sponsored': 54,
#    'count passed': 13,
#    'topic counts': {'Judiciary': 1,
#     'Government Accountability and Pensions': 4,
#     'Local Government': 1,
#     'Financial Institutions': 2,
#     'Education': 1,
#     'Personnel & Pensions Committee': 19,
#     'Elementary & Secondary Education: Administration, Licensing & Charter School': 1,
#     'Executive Committee': 13,
#     'Cities & Villages Committee': 1,
#     'Revenue & Finance Committee': 8,
#     'Labor & Commerce Committee': 1,
#     'Judiciary - Civil Committee': 1,
#     'Cybersecurity, Data Analytics, & IT Committee': 1}}},
#  'Michael P. McAuliffe': {'party': 'R',
#   'district': 'House 20',
#   'committees': [],
#   'bills': {'ids': ['SB1506',
#     'HB2080',
#     'HB2439',
#     'HB3279',
#     'HB3280',
#     'HB3824'],
#    'count sponsored': 6,
#    'count passed': 1,
#    'topic counts': {'Public Health': 1,
#     'Energy & Environment Committee': 1,
#     'Prescription Drug Affordability & Accessibility Committee': 1,
#     'Revenue & Finance Committee': 2}}},
#  'Christian L. Mitchell': {'party': 'D',
#   'district': 'House 26',
#   'committees': [],
#   'bills': {'ids': [],
#    'count sponsored': 0,
#    'count passed': 0,
#    'topic counts': {}}}}

# %% [markdown]
# #### Rep database

# %%
rep_data = []
for name in rep_info.keys():
    
    rep_data.append([name, 
                     rep_info[name]['party'], 
                     rep_info[name]['district'], 
                     rep_info[name]['count sponsored'],
                     rep_info[name]['count passed']])
